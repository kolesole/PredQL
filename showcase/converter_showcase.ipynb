# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

import pandas as pd

sys.path.append("..")

from relbench.datasets.f1 import F1Dataset

from showcase.showcase_helper import ConverterShowcaseHelper

# %% [markdown]
# #### TEMPORAL

# %%
f1_dataset = F1Dataset()
timestamps = pd.date_range(start="2010-01-01", end="2010-05-05", freq="D")

db = f1_dataset.get_db(upto_test_timestamp=False)
temporal_helper = ConverterShowcaseHelper(db, timestamps)
# Out:
# Making Database object from scratch...
# (You can also use `get_dataset(..., download=True)` for datasets prepared by the RelBench team.)
# Done in 0.20 seconds.

# %%
temporal_helper.convert_query("""
                PREDICT AVG(results.position, 0, 10, days) > 10
                FOR EACH drivers.driverId WHERE AVG(results.position, 
-365, 0, days) < 30;
              """)
# Out:
# ========================================
#
#                 PREDICT AVG(results.position, 0, 10, days) > 10
#                 FOR EACH drivers.driverId WHERE AVG(results.position,
# -365, 0, days) < 30;
#
# -365 0
# VALIDATE PREDICT
# VALIDATE PREDICT2222
# 1. ERROR at line 4:0 - Start and end time in temporal aggregation must be non-negative in PREDICT and WHERE clauses, found start=-365, end=0.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /home/kolesiko/CTU/BT/PredQL/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3709: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
temporal_helper.convert_query("""
                PREDICT AVG(results.position, 0, 100, days) > 10
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT AVG(results.position, 0, 100, days) > 10
#                 FOR EACH drivers.driverId;
#
# ------PREDICT_START------
# SELECT
#     parent.driverId AS fk,
#     time.timestamp AS timestamp,
#     CASE
#         WHEN main.fk IS NOT NULL THEN TRUE
#         ELSE FALSE
#     END
#  AS label
# FROM
#     drivers parent
# CROSS JOIN
#     timestamp_df time
# LEFT JOIN
#     (------CONDITION_START------
#     SELECT
#         *
#     FROM
#         (------AGGREGATION_START------
#         SELECT
#             parent.driverId AS fk,
#             AVG(aggr_tbl.position)
#          AS comp_col,
#             time.timestamp AS timestamp
#         FROM
#             drivers parent
#         CROSS JOIN
#             timestamp_df time
#         LEFT JOIN
#             results aggr_tbl
#         ON
#             aggr_tbl.driverId = parent.driverId
#         AND
#             aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#         AND
#             aggr_tbl.date < time.timestamp + INTERVAL '100 DAY'
#         GROUP BY
#             time.timestamp, parent.driverId
#         ------AGGREGATION_END------
#     )
#     WHERE
#         comp_col > 10
#     ------CONDITION_END------
# ) main
# ON
#     main.fk = parent.driverId
# AND
#     main.timestamp = time.timestamp
# ORDER BY
#     time.timestamp ASC, parent.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬─────────┐
# │  fk   │      timestamp      │  label  │
# │ int64 │    timestamp_ns     │ boolean │
# ├───────┼─────────────────────┼─────────┤
# │     0 │ 2010-01-01 00:00:00 │ false   │
# │     1 │ 2010-01-01 00:00:00 │ false   │
# │     2 │ 2010-01-01 00:00:00 │ false   │
# │     3 │ 2010-01-01 00:00:00 │ false   │
# │     4 │ 2010-01-01 00:00:00 │ true    │
# │     5 │ 2010-01-01 00:00:00 │ false   │
# │     6 │ 2010-01-01 00:00:00 │ false   │
# │     7 │ 2010-01-01 00:00:00 │ false   │
# │     8 │ 2010-01-01 00:00:00 │ false   │
# │     9 │ 2010-01-01 00:00:00 │ false   │
# │     · │          ·          │   ·     │
# │     · │          ·          │   ·     │
# │     · │          ·          │   ·     │
# │   563 │ 2010-01-12 00:00:00 │ false   │
# │   564 │ 2010-01-12 00:00:00 │ false   │
# │   565 │ 2010-01-12 00:00:00 │ false   │
# │   566 │ 2010-01-12 00:00:00 │ false   │
# │   567 │ 2010-01-12 00:00:00 │ false   │
# │   568 │ 2010-01-12 00:00:00 │ false   │
# │   569 │ 2010-01-12 00:00:00 │ false   │
# │   570 │ 2010-01-12 00:00:00 │ false   │
# │   571 │ 2010-01-12 00:00:00 │ false   │
# │   572 │ 2010-01-12 00:00:00 │ false   │
# ├───────┴─────────────────────┴─────────┤
# │ ? rows                      3 columns │
# │ (>9999 rows, 20 shown)                │
# └───────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %%
temporal_helper.convert_query("""
                PREDICT AVG(results.position, 0, 100, days)
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT AVG(results.position, 0, 100, days)
#                 FOR EACH drivers.driverId;
#
# ------PREDICT_START------
# SELECT
#     parent.driverId AS fk,
#     time.timestamp AS timestamp,
#     main.comp_col
#  AS label
# FROM
#     drivers parent
# CROSS JOIN
#     timestamp_df time
# LEFT JOIN
#     (------AGGREGATION_START------
#     SELECT
#         parent.driverId AS fk,
#         AVG(aggr_tbl.position)
#      AS comp_col,
#         time.timestamp AS timestamp
#     FROM
#         drivers parent
#     CROSS JOIN
#         timestamp_df time
#     LEFT JOIN
#         results aggr_tbl
#     ON
#         aggr_tbl.driverId = parent.driverId
#     AND
#         aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#     AND
#         aggr_tbl.date < time.timestamp + INTERVAL '100 DAY'
#     GROUP BY
#         time.timestamp, parent.driverId
#     ------AGGREGATION_END------
# ) main
# ON
#     main.fk = parent.driverId
# AND
#     main.timestamp = time.timestamp
# ORDER BY
#     time.timestamp ASC, parent.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬───────────────────┐
# │  fk   │      timestamp      │       label       │
# │ int64 │    timestamp_ns     │      double       │
# ├───────┼─────────────────────┼───────────────────┤
# │     0 │ 2010-01-01 00:00:00 │               5.0 │
# │     1 │ 2010-01-01 00:00:00 │              NULL │
# │     2 │ 2010-01-01 00:00:00 │ 4.333333333333333 │
# │     3 │ 2010-01-01 00:00:00 │               6.0 │
# │     4 │ 2010-01-01 00:00:00 │              14.0 │
# │     5 │ 2010-01-01 00:00:00 │              NULL │
# │     6 │ 2010-01-01 00:00:00 │              NULL │
# │     7 │ 2010-01-01 00:00:00 │              NULL │
# │     8 │ 2010-01-01 00:00:00 │ 5.666666666666667 │
# │     9 │ 2010-01-01 00:00:00 │              NULL │
# │     · │          ·          │                ·  │
# │     · │          ·          │                ·  │
# │     · │          ·          │                ·  │
# │   563 │ 2010-01-12 00:00:00 │              NULL │
# │   564 │ 2010-01-12 00:00:00 │              NULL │
# │   565 │ 2010-01-12 00:00:00 │              NULL │
# │   566 │ 2010-01-12 00:00:00 │              NULL │
# │   567 │ 2010-01-12 00:00:00 │              NULL │
# │   568 │ 2010-01-12 00:00:00 │              NULL │
# │   569 │ 2010-01-12 00:00:00 │              NULL │
# │   570 │ 2010-01-12 00:00:00 │              NULL │
# │   571 │ 2010-01-12 00:00:00 │              NULL │
# │   572 │ 2010-01-12 00:00:00 │              NULL │
# ├───────┴─────────────────────┴───────────────────┤
# │ ? rows (>9999 rows, 20 shown)         3 columns │
# └─────────────────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %%
temporal_helper.convert_query("""
                PREDICT NOT AVG(results.position, 0, 100, days) > 10
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT NOT AVG(results.position, 0, 100, days) > 10
#                 FOR EACH drivers.driverId;
#
# ------PREDICT_START------
# SELECT
#     parent.driverId AS fk,
#     time.timestamp AS timestamp,
#     CASE
#         WHEN main.fk IS NOT NULL THEN TRUE
#         ELSE FALSE
#     END
#  AS label
# FROM
#     drivers parent
# CROSS JOIN
#     timestamp_df time
# LEFT JOIN
#     (------CONDITION_START------
#     SELECT
#         *
#     FROM
#         (------AGGREGATION_START------
#         SELECT
#             parent.driverId AS fk,
#             AVG(aggr_tbl.position)
#          AS comp_col,
#             time.timestamp AS timestamp
#         FROM
#             drivers parent
#         CROSS JOIN
#             timestamp_df time
#         LEFT JOIN
#             results aggr_tbl
#         ON
#             aggr_tbl.driverId = parent.driverId
#         AND
#             aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#         AND
#             aggr_tbl.date < time.timestamp + INTERVAL '100 DAY'
#         GROUP BY
#             time.timestamp, parent.driverId
#         ------AGGREGATION_END------
#     )
#     WHERE
#         NOT comp_col > 10
#     ------CONDITION_END------
# ) main
# ON
#     main.fk = parent.driverId
# AND
#     main.timestamp = time.timestamp
# ORDER BY
#     time.timestamp ASC, parent.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬─────────┐
# │  fk   │      timestamp      │  label  │
# │ int64 │    timestamp_ns     │ boolean │
# ├───────┼─────────────────────┼─────────┤
# │     0 │ 2010-01-01 00:00:00 │ true    │
# │     1 │ 2010-01-01 00:00:00 │ false   │
# │     2 │ 2010-01-01 00:00:00 │ true    │
# │     3 │ 2010-01-01 00:00:00 │ true    │
# │     4 │ 2010-01-01 00:00:00 │ false   │
# │     5 │ 2010-01-01 00:00:00 │ false   │
# │     6 │ 2010-01-01 00:00:00 │ false   │
# │     7 │ 2010-01-01 00:00:00 │ false   │
# │     8 │ 2010-01-01 00:00:00 │ true    │
# │     9 │ 2010-01-01 00:00:00 │ false   │
# │     · │          ·          │   ·     │
# │     · │          ·          │   ·     │
# │     · │          ·          │   ·     │
# │   563 │ 2010-01-12 00:00:00 │ false   │
# │   564 │ 2010-01-12 00:00:00 │ false   │
# │   565 │ 2010-01-12 00:00:00 │ false   │
# │   566 │ 2010-01-12 00:00:00 │ false   │
# │   567 │ 2010-01-12 00:00:00 │ false   │
# │   568 │ 2010-01-12 00:00:00 │ false   │
# │   569 │ 2010-01-12 00:00:00 │ false   │
# │   570 │ 2010-01-12 00:00:00 │ false   │
# │   571 │ 2010-01-12 00:00:00 │ false   │
# │   572 │ 2010-01-12 00:00:00 │ false   │
# ├───────┴─────────────────────┴─────────┤
# │ ? rows                      3 columns │
# │ (>9999 rows, 20 shown)                │
# └───────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %%
temporal_helper.convert_query("""
                PREDICT AVG(results.position, 0, 700, days) > 10
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT AVG(results.position, 0, 700, days) > 10
#                 FOR EACH drivers.driverId;
#
# ------PREDICT_START------
# SELECT
#     parent.driverId AS fk,
#     time.timestamp AS timestamp,
#     CASE
#         WHEN main.fk IS NOT NULL THEN TRUE
#         ELSE FALSE
#     END
#  AS label
# FROM
#     drivers parent
# CROSS JOIN
#     timestamp_df time
# LEFT JOIN
#     (------CONDITION_START------
#     SELECT
#         *
#     FROM
#         (------AGGREGATION_START------
#         SELECT
#             parent.driverId AS fk,
#             AVG(aggr_tbl.position)
#          AS comp_col,
#             time.timestamp AS timestamp
#         FROM
#             drivers parent
#         CROSS JOIN
#             timestamp_df time
#         LEFT JOIN
#             results aggr_tbl
#         ON
#             aggr_tbl.driverId = parent.driverId
#         AND
#             aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#         AND
#             aggr_tbl.date < time.timestamp + INTERVAL '700 DAY'
#         GROUP BY
#             time.timestamp, parent.driverId
#         ------AGGREGATION_END------
#     )
#     WHERE
#         comp_col > 10
#     ------CONDITION_END------
# ) main
# ON
#     main.fk = parent.driverId
# AND
#     main.timestamp = time.timestamp
# ORDER BY
#     time.timestamp ASC, parent.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬─────────┐
# │  fk   │      timestamp      │  label  │
# │ int64 │    timestamp_ns     │ boolean │
# ├───────┼─────────────────────┼─────────┤
# │     0 │ 2010-01-01 00:00:00 │ false   │
# │     1 │ 2010-01-01 00:00:00 │ false   │
# │     2 │ 2010-01-01 00:00:00 │ false   │
# │     3 │ 2010-01-01 00:00:00 │ false   │
# │     4 │ 2010-01-01 00:00:00 │ true    │
# │     5 │ 2010-01-01 00:00:00 │ false   │
# │     6 │ 2010-01-01 00:00:00 │ false   │
# │     7 │ 2010-01-01 00:00:00 │ false   │
# │     8 │ 2010-01-01 00:00:00 │ false   │
# │     9 │ 2010-01-01 00:00:00 │ true    │
# │     · │          ·          │  ·      │
# │     · │          ·          │  ·      │
# │     · │          ·          │  ·      │
# │   563 │ 2010-01-12 00:00:00 │ false   │
# │   564 │ 2010-01-12 00:00:00 │ false   │
# │   565 │ 2010-01-12 00:00:00 │ false   │
# │   566 │ 2010-01-12 00:00:00 │ false   │
# │   567 │ 2010-01-12 00:00:00 │ false   │
# │   568 │ 2010-01-12 00:00:00 │ false   │
# │   569 │ 2010-01-12 00:00:00 │ false   │
# │   570 │ 2010-01-12 00:00:00 │ false   │
# │   571 │ 2010-01-12 00:00:00 │ false   │
# │   572 │ 2010-01-12 00:00:00 │ false   │
# ├───────┴─────────────────────┴─────────┤
# │ ? rows                      3 columns │
# │ (>9999 rows, 20 shown)                │
# └───────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %%
temporal_helper.convert_query("""
                PREDICT NOT AVG(results.position, 0, 700, days) > 10
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT NOT AVG(results.position, 0, 700, days) > 10
#                 FOR EACH drivers.driverId;
#
# ------PREDICT_START------
# SELECT
#     parent.driverId AS fk,
#     time.timestamp AS timestamp,
#     CASE
#         WHEN main.fk IS NOT NULL THEN TRUE
#         ELSE FALSE
#     END
#  AS label
# FROM
#     drivers parent
# CROSS JOIN
#     timestamp_df time
# LEFT JOIN
#     (------CONDITION_START------
#     SELECT
#         *
#     FROM
#         (------AGGREGATION_START------
#         SELECT
#             parent.driverId AS fk,
#             AVG(aggr_tbl.position)
#          AS comp_col,
#             time.timestamp AS timestamp
#         FROM
#             drivers parent
#         CROSS JOIN
#             timestamp_df time
#         LEFT JOIN
#             results aggr_tbl
#         ON
#             aggr_tbl.driverId = parent.driverId
#         AND
#             aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#         AND
#             aggr_tbl.date < time.timestamp + INTERVAL '700 DAY'
#         GROUP BY
#             time.timestamp, parent.driverId
#         ------AGGREGATION_END------
#     )
#     WHERE
#         NOT comp_col > 10
#     ------CONDITION_END------
# ) main
# ON
#     main.fk = parent.driverId
# AND
#     main.timestamp = time.timestamp
# ORDER BY
#     time.timestamp ASC, parent.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬─────────┐
# │  fk   │      timestamp      │  label  │
# │ int64 │    timestamp_ns     │ boolean │
# ├───────┼─────────────────────┼─────────┤
# │     0 │ 2010-01-01 00:00:00 │ true    │
# │     1 │ 2010-01-01 00:00:00 │ true    │
# │     2 │ 2010-01-01 00:00:00 │ true    │
# │     3 │ 2010-01-01 00:00:00 │ true    │
# │     4 │ 2010-01-01 00:00:00 │ false   │
# │     5 │ 2010-01-01 00:00:00 │ false   │
# │     6 │ 2010-01-01 00:00:00 │ false   │
# │     7 │ 2010-01-01 00:00:00 │ false   │
# │     8 │ 2010-01-01 00:00:00 │ true    │
# │     9 │ 2010-01-01 00:00:00 │ false   │
# │     · │          ·          │   ·     │
# │     · │          ·          │   ·     │
# │     · │          ·          │   ·     │
# │   563 │ 2010-01-12 00:00:00 │ false   │
# │   564 │ 2010-01-12 00:00:00 │ false   │
# │   565 │ 2010-01-12 00:00:00 │ false   │
# │   566 │ 2010-01-12 00:00:00 │ false   │
# │   567 │ 2010-01-12 00:00:00 │ false   │
# │   568 │ 2010-01-12 00:00:00 │ false   │
# │   569 │ 2010-01-12 00:00:00 │ false   │
# │   570 │ 2010-01-12 00:00:00 │ false   │
# │   571 │ 2010-01-12 00:00:00 │ false   │
# │   572 │ 2010-01-12 00:00:00 │ false   │
# ├───────┴─────────────────────┴─────────┤
# │ ? rows                      3 columns │
# │ (>9999 rows, 20 shown)                │
# └───────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %%
temporal_helper.convert_query("""
                PREDICT AVG(results.position, 0, 10, days) > 10
                FOR EACH drivers.driverId WHERE AVG(results.position, -365, 0, days) < 30 AND AVG(results.position, -365, 0, days) >= 0;
              """)
# Out:
# ========================================
#
#                 PREDICT AVG(results.position, 0, 10, days) > 10
#                 FOR EACH drivers.driverId WHERE AVG(results.position, -365, 0, days) < 30 AND AVG(results.position, -365, 0, days) >= 0;
#
# ------PREDICT_START------
# SELECT
#     help.driverId AS fk,
#     help.timestamp,
#     CASE
#         WHEN main.fk IS NOT NULL THEN TRUE
#         ELSE FALSE
#     END
#  AS label
# FROM
#     (
# ------HELP_PART_START------
#     SELECT
#         parent.driverId,
#         for_each.timestamp,
#     FROM
#         drivers parent
#     JOIN
#         (------EXPR_START------
#     SELECT
#         fk,
#         timestamp
#     FROM
#         (------CONDITION_START------
#         SELECT
#             *
#         FROM
#             (------AGGREGATION_START------
#             SELECT
#                 parent.driverId AS fk,
#                 AVG(aggr_tbl.position)
#              AS comp_col,
#                 time.timestamp AS timestamp
#             FROM
#                 drivers parent
#             CROSS JOIN
#                 timestamp_df time
#             LEFT JOIN
#                 results aggr_tbl
#             ON
#                 aggr_tbl.driverId = parent.driverId
#             AND
#                 aggr_tbl.date >= time.timestamp + INTERVAL '-365 DAY'
#             AND
#                 aggr_tbl.date < time.timestamp + INTERVAL '0 DAY'
#             GROUP BY
#                 time.timestamp, parent.driverId
#             ------AGGREGATION_END------
#         )
#         WHERE
#             comp_col < 30
#         ------CONDITION_END------
#     ) left_expr
#     INTERSECT
#     SELECT
#         fk,
#         timestamp
#     FROM
#         (------CONDITION_START------
#         SELECT
#             *
#         FROM
#             (------AGGREGATION_START------
#             SELECT
#                 parent.driverId AS fk,
#                 AVG(aggr_tbl.position)
#              AS comp_col,
#                 time.timestamp AS timestamp
#             FROM
#                 drivers parent
#             CROSS JOIN
#                 timestamp_df time
#             LEFT JOIN
#                 results aggr_tbl
#             ON
#                 aggr_tbl.driverId = parent.driverId
#             AND
#                 aggr_tbl.date >= time.timestamp + INTERVAL '-365 DAY'
#             AND
#                 aggr_tbl.date < time.timestamp + INTERVAL '0 DAY'
#             GROUP BY
#                 time.timestamp, parent.driverId
#             ------AGGREGATION_END------
#         )
#         WHERE
#             comp_col >= 0
#         ------CONDITION_END------
#     ) right_expr
#     ------EXPR_END------
# ) for_each
#     ON
#         for_each.fk = parent.driverId
# ------HELP_PART_END------
#     ) help
# LEFT JOIN
#     (------CONDITION_START------
#     SELECT
#         *
#     FROM
#         (------AGGREGATION_START------
#         SELECT
#             parent.driverId AS fk,
#             AVG(aggr_tbl.position)
#          AS comp_col,
#             time.timestamp AS timestamp
#         FROM
#             drivers parent
#         CROSS JOIN
#             timestamp_df time
#         LEFT JOIN
#             results aggr_tbl
#         ON
#             aggr_tbl.driverId = parent.driverId
#         AND
#             aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#         AND
#             aggr_tbl.date < time.timestamp + INTERVAL '10 DAY'
#         GROUP BY
#             time.timestamp, parent.driverId
#         ------AGGREGATION_END------
#     )
#     WHERE
#         comp_col > 10
#     ------CONDITION_END------
# ) main
# ON
#     main.fk = help.driverId
# AND
#     main.timestamp = help.timestamp
# ORDER BY
#     help.timestamp ASC, help.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬─────────┐
# │  fk   │      timestamp      │  label  │
# │ int64 │    timestamp_ns     │ boolean │
# ├───────┼─────────────────────┼─────────┤
# │     0 │ 2010-01-01 00:00:00 │ false   │
# │     1 │ 2010-01-01 00:00:00 │ false   │
# │     2 │ 2010-01-01 00:00:00 │ false   │
# │     3 │ 2010-01-01 00:00:00 │ false   │
# │     4 │ 2010-01-01 00:00:00 │ false   │
# │     5 │ 2010-01-01 00:00:00 │ false   │
# │     6 │ 2010-01-01 00:00:00 │ false   │
# │     7 │ 2010-01-01 00:00:00 │ false   │
# │     8 │ 2010-01-01 00:00:00 │ false   │
# │     9 │ 2010-01-01 00:00:00 │ false   │
# │     · │          ·          │   ·     │
# │     · │          ·          │   ·     │
# │     · │          ·          │   ·     │
# │    66 │ 2010-05-05 00:00:00 │ false   │
# │    68 │ 2010-05-05 00:00:00 │ false   │
# │   152 │ 2010-05-05 00:00:00 │ false   │
# │   153 │ 2010-05-05 00:00:00 │ false   │
# │   154 │ 2010-05-05 00:00:00 │ true    │
# │   807 │ 2010-05-05 00:00:00 │ true    │
# │   808 │ 2010-05-05 00:00:00 │ true    │
# │   809 │ 2010-05-05 00:00:00 │ true    │
# │   810 │ 2010-05-05 00:00:00 │ false   │
# │   811 │ 2010-05-05 00:00:00 │ false   │
# ├───────┴─────────────────────┴─────────┤
# │ 3384 rows (20 shown)        3 columns │
# └───────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %%
temporal_helper.convert_query("""
                PREDICT AVG(results.position, 0, 100, days) < 100
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT AVG(results.position, 0, 100, days) < 100
#                 FOR EACH drivers.driverId;
#
# ------PREDICT_START------
# SELECT
#     parent.driverId AS fk,
#     time.timestamp AS timestamp,
#     CASE
#         WHEN main.fk IS NOT NULL THEN TRUE
#         ELSE FALSE
#     END
#  AS label
# FROM
#     drivers parent
# CROSS JOIN
#     timestamp_df time
# LEFT JOIN
#     (------CONDITION_START------
#     SELECT
#         *
#     FROM
#         (------AGGREGATION_START------
#         SELECT
#             parent.driverId AS fk,
#             AVG(aggr_tbl.position)
#          AS comp_col,
#             time.timestamp AS timestamp
#         FROM
#             drivers parent
#         CROSS JOIN
#             timestamp_df time
#         LEFT JOIN
#             results aggr_tbl
#         ON
#             aggr_tbl.driverId = parent.driverId
#         AND
#             aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#         AND
#             aggr_tbl.date < time.timestamp + INTERVAL '100 DAY'
#         GROUP BY
#             time.timestamp, parent.driverId
#         ------AGGREGATION_END------
#     )
#     WHERE
#         comp_col < 100
#     ------CONDITION_END------
# ) main
# ON
#     main.fk = parent.driverId
# AND
#     main.timestamp = time.timestamp
# ORDER BY
#     time.timestamp ASC, parent.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬─────────┐
# │  fk   │      timestamp      │  label  │
# │ int64 │    timestamp_ns     │ boolean │
# ├───────┼─────────────────────┼─────────┤
# │     0 │ 2010-01-01 00:00:00 │ true    │
# │     1 │ 2010-01-01 00:00:00 │ false   │
# │     2 │ 2010-01-01 00:00:00 │ true    │
# │     3 │ 2010-01-01 00:00:00 │ true    │
# │     4 │ 2010-01-01 00:00:00 │ true    │
# │     5 │ 2010-01-01 00:00:00 │ false   │
# │     6 │ 2010-01-01 00:00:00 │ false   │
# │     7 │ 2010-01-01 00:00:00 │ false   │
# │     8 │ 2010-01-01 00:00:00 │ true    │
# │     9 │ 2010-01-01 00:00:00 │ false   │
# │     · │          ·          │   ·     │
# │     · │          ·          │   ·     │
# │     · │          ·          │   ·     │
# │   563 │ 2010-01-12 00:00:00 │ false   │
# │   564 │ 2010-01-12 00:00:00 │ false   │
# │   565 │ 2010-01-12 00:00:00 │ false   │
# │   566 │ 2010-01-12 00:00:00 │ false   │
# │   567 │ 2010-01-12 00:00:00 │ false   │
# │   568 │ 2010-01-12 00:00:00 │ false   │
# │   569 │ 2010-01-12 00:00:00 │ false   │
# │   570 │ 2010-01-12 00:00:00 │ false   │
# │   571 │ 2010-01-12 00:00:00 │ false   │
# │   572 │ 2010-01-12 00:00:00 │ false   │
# ├───────┴─────────────────────┴─────────┤
# │ ? rows                      3 columns │
# │ (>9999 rows, 20 shown)                │
# └───────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %%
temporal_helper.convert_query("""
                PREDICT COUNT(results.*, 0, 100, days) < 100
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT COUNT(results.*, 0, 100, days) < 100
#                 FOR EACH drivers.driverId;
#
# ------PREDICT_START------
# SELECT
#     parent.driverId AS fk,
#     time.timestamp AS timestamp,
#     CASE
#         WHEN main.fk IS NOT NULL THEN TRUE
#         ELSE FALSE
#     END
#  AS label
# FROM
#     drivers parent
# CROSS JOIN
#     timestamp_df time
# LEFT JOIN
#     (------CONDITION_START------
#     SELECT
#         *
#     FROM
#         (------AGGREGATION_START------
#         SELECT
#             parent.driverId AS fk,
#             COUNT(aggr_tbl.*)
#          AS comp_col,
#             time.timestamp AS timestamp
#         FROM
#             drivers parent
#         CROSS JOIN
#             timestamp_df time
#         LEFT JOIN
#             results aggr_tbl
#         ON
#             aggr_tbl.driverId = parent.driverId
#         AND
#             aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#         AND
#             aggr_tbl.date < time.timestamp + INTERVAL '100 DAY'
#         GROUP BY
#             time.timestamp, parent.driverId
#         ------AGGREGATION_END------
#     )
#     WHERE
#         comp_col < 100
#     ------CONDITION_END------
# ) main
# ON
#     main.fk = parent.driverId
# AND
#     main.timestamp = time.timestamp
# ORDER BY
#     time.timestamp ASC, parent.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬─────────┐
# │  fk   │      timestamp      │  label  │
# │ int64 │    timestamp_ns     │ boolean │
# ├───────┼─────────────────────┼─────────┤
# │     0 │ 2010-01-01 00:00:00 │ true    │
# │     1 │ 2010-01-01 00:00:00 │ true    │
# │     2 │ 2010-01-01 00:00:00 │ true    │
# │     3 │ 2010-01-01 00:00:00 │ true    │
# │     4 │ 2010-01-01 00:00:00 │ true    │
# │     5 │ 2010-01-01 00:00:00 │ true    │
# │     6 │ 2010-01-01 00:00:00 │ true    │
# │     7 │ 2010-01-01 00:00:00 │ true    │
# │     8 │ 2010-01-01 00:00:00 │ true    │
# │     9 │ 2010-01-01 00:00:00 │ true    │
# │     · │          ·          │  ·      │
# │     · │          ·          │  ·      │
# │     · │          ·          │  ·      │
# │   563 │ 2010-01-12 00:00:00 │ true    │
# │   564 │ 2010-01-12 00:00:00 │ true    │
# │   565 │ 2010-01-12 00:00:00 │ true    │
# │   566 │ 2010-01-12 00:00:00 │ true    │
# │   567 │ 2010-01-12 00:00:00 │ true    │
# │   568 │ 2010-01-12 00:00:00 │ true    │
# │   569 │ 2010-01-12 00:00:00 │ true    │
# │   570 │ 2010-01-12 00:00:00 │ true    │
# │   571 │ 2010-01-12 00:00:00 │ true    │
# │   572 │ 2010-01-12 00:00:00 │ true    │
# ├───────┴─────────────────────┴─────────┤
# │ ? rows                      3 columns │
# │ (>9999 rows, 20 shown)                │
# └───────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %%
temporal_helper.convert_query("""
                PREDICT AVG(results.position, 0, 100, days)
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT AVG(results.position, 0, 100, days)
#                 FOR EACH drivers.driverId;
#
# ------PREDICT_START------
# SELECT
#     parent.driverId AS fk,
#     time.timestamp AS timestamp,
#     main.comp_col
#  AS label
# FROM
#     drivers parent
# CROSS JOIN
#     timestamp_df time
# LEFT JOIN
#     (------AGGREGATION_START------
#     SELECT
#         parent.driverId AS fk,
#         AVG(aggr_tbl.position)
#      AS comp_col,
#         time.timestamp AS timestamp
#     FROM
#         drivers parent
#     CROSS JOIN
#         timestamp_df time
#     LEFT JOIN
#         results aggr_tbl
#     ON
#         aggr_tbl.driverId = parent.driverId
#     AND
#         aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#     AND
#         aggr_tbl.date < time.timestamp + INTERVAL '100 DAY'
#     GROUP BY
#         time.timestamp, parent.driverId
#     ------AGGREGATION_END------
# ) main
# ON
#     main.fk = parent.driverId
# AND
#     main.timestamp = time.timestamp
# ORDER BY
#     time.timestamp ASC, parent.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬───────────────────┐
# │  fk   │      timestamp      │       label       │
# │ int64 │    timestamp_ns     │      double       │
# ├───────┼─────────────────────┼───────────────────┤
# │     0 │ 2010-01-01 00:00:00 │               5.0 │
# │     1 │ 2010-01-01 00:00:00 │              NULL │
# │     2 │ 2010-01-01 00:00:00 │ 4.333333333333333 │
# │     3 │ 2010-01-01 00:00:00 │               6.0 │
# │     4 │ 2010-01-01 00:00:00 │              14.0 │
# │     5 │ 2010-01-01 00:00:00 │              NULL │
# │     6 │ 2010-01-01 00:00:00 │              NULL │
# │     7 │ 2010-01-01 00:00:00 │              NULL │
# │     8 │ 2010-01-01 00:00:00 │ 5.666666666666667 │
# │     9 │ 2010-01-01 00:00:00 │              NULL │
# │     · │          ·          │                ·  │
# │     · │          ·          │                ·  │
# │     · │          ·          │                ·  │
# │   563 │ 2010-01-12 00:00:00 │              NULL │
# │   564 │ 2010-01-12 00:00:00 │              NULL │
# │   565 │ 2010-01-12 00:00:00 │              NULL │
# │   566 │ 2010-01-12 00:00:00 │              NULL │
# │   567 │ 2010-01-12 00:00:00 │              NULL │
# │   568 │ 2010-01-12 00:00:00 │              NULL │
# │   569 │ 2010-01-12 00:00:00 │              NULL │
# │   570 │ 2010-01-12 00:00:00 │              NULL │
# │   571 │ 2010-01-12 00:00:00 │              NULL │
# │   572 │ 2010-01-12 00:00:00 │              NULL │
# ├───────┴─────────────────────┴───────────────────┤
# │ ? rows (>9999 rows, 20 shown)         3 columns │
# └─────────────────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %%
temporal_helper.convert_query("""
                PREDICT AVG(results.position WHERE drivers.driverId < 5, 0, 100, days)
                FOR EACH drivers.driverId WHERE COUNT(results.*, 0, 100, days) > 5
                WHERE AVG(results.position, -365, 0, days) < 30;
              """)
# Out:
# ========================================
#
#                 PREDICT AVG(results.position WHERE drivers.driverId < 5, 0, 100, days)
#                 FOR EACH drivers.driverId WHERE COUNT(results.*, 0, 100, days) > 5
#                 WHERE AVG(results.position, -365, 0, days) < 30;
#
# SELECT
#     sq.fk,
#     sq.timestamp,
#     sq.label
# FROM
#     (------PREDICT_START------
#     SELECT
#         help.driverId AS fk,
#         help.timestamp,
#         main.comp_col
#      AS label
#     FROM
#         (
#     ------HELP_PART_START------
#         SELECT
#             parent.driverId,
#             for_each.timestamp,
#         FROM
#             drivers parent
#         JOIN
#             (------CONDITION_START------
#         SELECT
#             *
#         FROM
#             (------AGGREGATION_START------
#             SELECT
#                 parent.driverId AS fk,
#                 COUNT(aggr_tbl.*)
#              AS comp_col,
#                 time.timestamp AS timestamp
#             FROM
#                 drivers parent
#             CROSS JOIN
#                 timestamp_df time
#             LEFT JOIN
#                 results aggr_tbl
#             ON
#                 aggr_tbl.driverId = parent.driverId
#             AND
#                 aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#             AND
#                 aggr_tbl.date < time.timestamp + INTERVAL '100 DAY'
#             GROUP BY
#                 time.timestamp, parent.driverId
#             ------AGGREGATION_END------
#         )
#         WHERE
#             comp_col > 5
#         ------CONDITION_END------
#     ) for_each
#         ON
#             for_each.fk = parent.driverId
#     ------HELP_PART_END------
#         ) help
#     LEFT JOIN
#         (------AGGREGATION_START------
#         SELECT
#             parent.driverId AS fk,
#             AVG(aggr_tbl.position)
#          AS comp_col,
#             time.timestamp AS timestamp
#         FROM
#             drivers parent
#         CROSS JOIN
#             timestamp_df time
#         LEFT JOIN
#             results aggr_tbl
#         ON
#             aggr_tbl.driverId = parent.driverId
#         AND
#             aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#         AND
#             aggr_tbl.date < time.timestamp + INTERVAL '100 DAY'
#         GROUP BY
#             time.timestamp, parent.driverId
#         ------AGGREGATION_END------
#     ) main
#     ON
#         main.fk = help.driverId
#     AND
#         main.timestamp = help.timestamp
#     ORDER BY
#         help.timestamp ASC, help.driverId ASC
#     ------PREDICT_END------
# ) sq
# JOIN
#     (------CONDITION_START------
#     SELECT
#         *
#     FROM
#         (------ID_DOT_ID_START------
#         SELECT
#             driverId AS fk,
#             driverId AS comp_col
#         FROM
#             drivers
#         ------ID_DOT_ID_END------
#     )
#     WHERE
#         comp_col < 5
#     ------CONDITION_END------
# ) hq
# ON
#     hq.fk = sq.fk
# ORDER BY
#     sq.timestamp ASC, sq.fk ASC
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬────────────────────┐
# │  fk   │      timestamp      │       label        │
# │ int64 │    timestamp_ns     │       double       │
# ├───────┼─────────────────────┼────────────────────┤
# │     0 │ 2010-02-06 00:00:00 │                6.0 │
# │     2 │ 2010-02-06 00:00:00 │                6.0 │
# │     3 │ 2010-02-06 00:00:00 │                5.0 │
# │     4 │ 2010-02-06 00:00:00 │               14.0 │
# │     0 │ 2010-02-07 00:00:00 │                6.0 │
# │     2 │ 2010-02-07 00:00:00 │                6.0 │
# │     3 │ 2010-02-07 00:00:00 │                5.0 │
# │     4 │ 2010-02-07 00:00:00 │               14.0 │
# │     0 │ 2010-02-08 00:00:00 │                6.0 │
# │     2 │ 2010-02-08 00:00:00 │                6.0 │
# │     · │          ·          │                 ·  │
# │     · │          ·          │                 ·  │
# │     · │          ·          │                 ·  │
# │     3 │ 2010-05-03 00:00:00 │                5.5 │
# │     4 │ 2010-05-03 00:00:00 │ 15.666666666666666 │
# │     0 │ 2010-05-04 00:00:00 │  4.142857142857143 │
# │     2 │ 2010-05-04 00:00:00 │  7.428571428571429 │
# │     3 │ 2010-05-04 00:00:00 │                5.5 │
# │     4 │ 2010-05-04 00:00:00 │ 15.666666666666666 │
# │     0 │ 2010-05-05 00:00:00 │  4.142857142857143 │
# │     2 │ 2010-05-05 00:00:00 │  7.428571428571429 │
# │     3 │ 2010-05-05 00:00:00 │                5.5 │
# │     4 │ 2010-05-05 00:00:00 │ 15.666666666666666 │
# ├───────┴─────────────────────┴────────────────────┤
# │ 356 rows (20 shown)                    3 columns │
# └──────────────────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %%
temporal_helper.convert_query("""
                PREDICT LIST_DISTINCT(results.position, 0, 100, days)
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT LIST_DISTINCT(results.position, 0, 100, days)
#                 FOR EACH drivers.driverId;
#
# ------PREDICT_START------
# SELECT
#     parent.driverId AS fk,
#     time.timestamp AS timestamp,
#     main.comp_col
#  AS label
# FROM
#     drivers parent
# CROSS JOIN
#     timestamp_df time
# LEFT JOIN
#     (------AGGREGATION_START------
#     SELECT
#         parent.driverId AS fk,
#         (
#         SELECT
#             ARRAY_AGG(freq_tbl.val ORDER BY freq_tbl.freq DESC)
#         FROM (
#             SELECT
#                 in_tbl.position AS val,
#                 COUNT(*) AS freq
#             FROM
#                 results in_tbl
#             WHERE
#                 in_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#             AND
#                 in_tbl.date <  time.timestamp + INTERVAL '100 DAY'
#             AND
#                 in_tbl.driverId = parent.driverId
#             GROUP BY in_tbl.position
#             ) freq_tbl
#         )
#      AS comp_col,
#         time.timestamp AS timestamp
#     FROM
#         drivers parent
#     CROSS JOIN
#         timestamp_df time
#     LEFT JOIN
#         results aggr_tbl
#     ON
#         aggr_tbl.driverId = parent.driverId
#     AND
#         aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#     AND
#         aggr_tbl.date < time.timestamp + INTERVAL '100 DAY'
#     GROUP BY
#         time.timestamp, parent.driverId
#     ------AGGREGATION_END------
# ) main
# ON
#     main.fk = parent.driverId
# AND
#     main.timestamp = time.timestamp
# ORDER BY
#     time.timestamp ASC, parent.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬────────────────────┐
# │  fk   │      timestamp      │       label        │
# │ int64 │    timestamp_ns     │      double[]      │
# ├───────┼─────────────────────┼────────────────────┤
# │     0 │ 2010-01-01 00:00:00 │ [6.0, 3.0]         │
# │     1 │ 2010-01-01 00:00:00 │ NULL               │
# │     2 │ 2010-01-01 00:00:00 │ [5.0, 3.0]         │
# │     3 │ 2010-01-01 00:00:00 │ [4.0, 13.0, 1.0]   │
# │     4 │ 2010-01-01 00:00:00 │ [15.0, NULL, 13.0] │
# │     5 │ 2010-01-01 00:00:00 │ NULL               │
# │     6 │ 2010-01-01 00:00:00 │ NULL               │
# │     7 │ 2010-01-01 00:00:00 │ NULL               │
# │     8 │ 2010-01-01 00:00:00 │ [11.0, 4.0, 2.0]   │
# │     9 │ 2010-01-01 00:00:00 │ [NULL]             │
# │     · │          ·          │  ·                 │
# │     · │          ·          │  ·                 │
# │     · │          ·          │  ·                 │
# │   563 │ 2010-01-12 00:00:00 │ NULL               │
# │   564 │ 2010-01-12 00:00:00 │ NULL               │
# │   565 │ 2010-01-12 00:00:00 │ NULL               │
# │   566 │ 2010-01-12 00:00:00 │ NULL               │
# │   567 │ 2010-01-12 00:00:00 │ NULL               │
# │   568 │ 2010-01-12 00:00:00 │ NULL               │
# │   569 │ 2010-01-12 00:00:00 │ NULL               │
# │   570 │ 2010-01-12 00:00:00 │ NULL               │
# │   571 │ 2010-01-12 00:00:00 │ NULL               │
# │   572 │ 2010-01-12 00:00:00 │ NULL               │
# ├───────┴─────────────────────┴────────────────────┤
# │ ? rows (>9999 rows, 20 shown)          3 columns │
# └──────────────────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %%
temporal_helper.convert_query("""
                PREDICT first(results.position, 0, 100, days)
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT first(results.position, 0, 100, days)
#                 FOR EACH drivers.driverId;
#
# ------PREDICT_START------
# SELECT
#     parent.driverId AS fk,
#     time.timestamp AS timestamp,
#     main.comp_col
#  AS label
# FROM
#     drivers parent
# CROSS JOIN
#     timestamp_df time
# LEFT JOIN
#     (------AGGREGATION_START------
#     SELECT
#         parent.driverId AS fk,
#         ARRAY_AGG(aggr_tbl.position ORDER BY aggr_tbl.date ASC)[1]
#      AS comp_col,
#         time.timestamp AS timestamp
#     FROM
#         drivers parent
#     CROSS JOIN
#         timestamp_df time
#     LEFT JOIN
#         results aggr_tbl
#     ON
#         aggr_tbl.driverId = parent.driverId
#     AND
#         aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#     AND
#         aggr_tbl.date < time.timestamp + INTERVAL '100 DAY'
#     GROUP BY
#         time.timestamp, parent.driverId
#     ------AGGREGATION_END------
# ) main
# ON
#     main.fk = parent.driverId
# AND
#     main.timestamp = time.timestamp
# ORDER BY
#     time.timestamp ASC, parent.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬────────┐
# │  fk   │      timestamp      │ label  │
# │ int64 │    timestamp_ns     │ double │
# ├───────┼─────────────────────┼────────┤
# │     0 │ 2010-01-01 00:00:00 │    3.0 │
# │     1 │ 2010-01-01 00:00:00 │   NULL │
# │     2 │ 2010-01-01 00:00:00 │    5.0 │
# │     3 │ 2010-01-01 00:00:00 │    1.0 │
# │     4 │ 2010-01-01 00:00:00 │   15.0 │
# │     5 │ 2010-01-01 00:00:00 │   NULL │
# │     6 │ 2010-01-01 00:00:00 │   NULL │
# │     7 │ 2010-01-01 00:00:00 │   NULL │
# │     8 │ 2010-01-01 00:00:00 │   11.0 │
# │     9 │ 2010-01-01 00:00:00 │   NULL │
# │     · │          ·          │     ·  │
# │     · │          ·          │     ·  │
# │     · │          ·          │     ·  │
# │   563 │ 2010-01-12 00:00:00 │   NULL │
# │   564 │ 2010-01-12 00:00:00 │   NULL │
# │   565 │ 2010-01-12 00:00:00 │   NULL │
# │   566 │ 2010-01-12 00:00:00 │   NULL │
# │   567 │ 2010-01-12 00:00:00 │   NULL │
# │   568 │ 2010-01-12 00:00:00 │   NULL │
# │   569 │ 2010-01-12 00:00:00 │   NULL │
# │   570 │ 2010-01-12 00:00:00 │   NULL │
# │   571 │ 2010-01-12 00:00:00 │   NULL │
# │   572 │ 2010-01-12 00:00:00 │   NULL │
# ├───────┴─────────────────────┴────────┤
# │ ? rows                     3 columns │
# │ (>9999 rows, 20 shown)               │
# └──────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %%
temporal_helper.convert_query("""
                PREDICT LIST_DISTINCT(results.position, 0, 100, days) CLASSIFY
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT LIST_DISTINCT(results.position, 0, 100, days) CLASSIFY
#                 FOR EACH drivers.driverId;
#
# ------PREDICT_START------
# SELECT
#     parent.driverId AS fk,
#     time.timestamp AS timestamp,
#     main.comp_col
#  AS label
# FROM
#     drivers parent
# CROSS JOIN
#     timestamp_df time
# LEFT JOIN
#     (------AGGREGATION_START------
#     SELECT
#         parent.driverId AS fk,
#         (
#         SELECT
#             ARRAY_AGG(freq_tbl.val ORDER BY freq_tbl.freq DESC)
#         FROM (
#             SELECT
#                 in_tbl.position AS val,
#                 COUNT(*) AS freq
#             FROM
#                 results in_tbl
#             WHERE
#                 in_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#             AND
#                 in_tbl.date <  time.timestamp + INTERVAL '100 DAY'
#             AND
#                 in_tbl.driverId = parent.driverId
#             GROUP BY in_tbl.position
#             ) freq_tbl
#         )
#      AS comp_col,
#         time.timestamp AS timestamp
#     FROM
#         drivers parent
#     CROSS JOIN
#         timestamp_df time
#     LEFT JOIN
#         results aggr_tbl
#     ON
#         aggr_tbl.driverId = parent.driverId
#     AND
#         aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#     AND
#         aggr_tbl.date < time.timestamp + INTERVAL '100 DAY'
#     GROUP BY
#         time.timestamp, parent.driverId
#     ------AGGREGATION_END------
# ) main
# ON
#     main.fk = parent.driverId
# AND
#     main.timestamp = time.timestamp
# ORDER BY
#     time.timestamp ASC, parent.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬────────────────────┐
# │  fk   │      timestamp      │       label        │
# │ int64 │    timestamp_ns     │      double[]      │
# ├───────┼─────────────────────┼────────────────────┤
# │     0 │ 2010-01-01 00:00:00 │ [6.0, 3.0]         │
# │     1 │ 2010-01-01 00:00:00 │ NULL               │
# │     2 │ 2010-01-01 00:00:00 │ [5.0, 3.0]         │
# │     3 │ 2010-01-01 00:00:00 │ [1.0, 4.0, 13.0]   │
# │     4 │ 2010-01-01 00:00:00 │ [NULL, 13.0, 15.0] │
# │     5 │ 2010-01-01 00:00:00 │ NULL               │
# │     6 │ 2010-01-01 00:00:00 │ NULL               │
# │     7 │ 2010-01-01 00:00:00 │ NULL               │
# │     8 │ 2010-01-01 00:00:00 │ [11.0, 4.0, 2.0]   │
# │     9 │ 2010-01-01 00:00:00 │ [NULL]             │
# │     · │          ·          │  ·                 │
# │     · │          ·          │  ·                 │
# │     · │          ·          │  ·                 │
# │   563 │ 2010-01-12 00:00:00 │ NULL               │
# │   564 │ 2010-01-12 00:00:00 │ NULL               │
# │   565 │ 2010-01-12 00:00:00 │ NULL               │
# │   566 │ 2010-01-12 00:00:00 │ NULL               │
# │   567 │ 2010-01-12 00:00:00 │ NULL               │
# │   568 │ 2010-01-12 00:00:00 │ NULL               │
# │   569 │ 2010-01-12 00:00:00 │ NULL               │
# │   570 │ 2010-01-12 00:00:00 │ NULL               │
# │   571 │ 2010-01-12 00:00:00 │ NULL               │
# │   572 │ 2010-01-12 00:00:00 │ NULL               │
# ├───────┴─────────────────────┴────────────────────┤
# │ ? rows (>9999 rows, 20 shown)          3 columns │
# └──────────────────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %%
temporal_helper.convert_query("""
                PREDICT LIST_DISTINCT(results.position, 0, 100, days) RANK TOP 2
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT LIST_DISTINCT(results.position, 0, 100, days) RANK TOP 2
#                 FOR EACH drivers.driverId;
#
# ------PREDICT_START------
# SELECT
#     parent.driverId AS fk,
#     time.timestamp AS timestamp,
#     CASE
#         WHEN ARRAY_LENGTH(main.comp_col) > 2 THEN main.comp_col[1:2]
#         ELSE main.comp_col
#     END
#  AS label
# FROM
#     drivers parent
# CROSS JOIN
#     timestamp_df time
# LEFT JOIN
#     (------AGGREGATION_START------
#     SELECT
#         parent.driverId AS fk,
#         (
#         SELECT
#             ARRAY_AGG(freq_tbl.val ORDER BY freq_tbl.freq DESC)
#         FROM (
#             SELECT
#                 in_tbl.position AS val,
#                 COUNT(*) AS freq
#             FROM
#                 results in_tbl
#             WHERE
#                 in_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#             AND
#                 in_tbl.date <  time.timestamp + INTERVAL '100 DAY'
#             AND
#                 in_tbl.driverId = parent.driverId
#             GROUP BY in_tbl.position
#             ) freq_tbl
#         )
#      AS comp_col,
#         time.timestamp AS timestamp
#     FROM
#         drivers parent
#     CROSS JOIN
#         timestamp_df time
#     LEFT JOIN
#         results aggr_tbl
#     ON
#         aggr_tbl.driverId = parent.driverId
#     AND
#         aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#     AND
#         aggr_tbl.date < time.timestamp + INTERVAL '100 DAY'
#     GROUP BY
#         time.timestamp, parent.driverId
#     ------AGGREGATION_END------
# ) main
# ON
#     main.fk = parent.driverId
# AND
#     main.timestamp = time.timestamp
# ORDER BY
#     time.timestamp ASC, parent.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬──────────────┐
# │  fk   │      timestamp      │    label     │
# │ int64 │    timestamp_ns     │   double[]   │
# ├───────┼─────────────────────┼──────────────┤
# │     0 │ 2010-01-01 00:00:00 │ [6.0, 3.0]   │
# │     1 │ 2010-01-01 00:00:00 │ NULL         │
# │     2 │ 2010-01-01 00:00:00 │ [5.0, 3.0]   │
# │     3 │ 2010-01-01 00:00:00 │ [4.0, 1.0]   │
# │     4 │ 2010-01-01 00:00:00 │ [15.0, NULL] │
# │     5 │ 2010-01-01 00:00:00 │ NULL         │
# │     6 │ 2010-01-01 00:00:00 │ NULL         │
# │     7 │ 2010-01-01 00:00:00 │ NULL         │
# │     8 │ 2010-01-01 00:00:00 │ [11.0, 4.0]  │
# │     9 │ 2010-01-01 00:00:00 │ [NULL]       │
# │     · │          ·          │  ·           │
# │     · │          ·          │  ·           │
# │     · │          ·          │  ·           │
# │   563 │ 2010-01-12 00:00:00 │ NULL         │
# │   564 │ 2010-01-12 00:00:00 │ NULL         │
# │   565 │ 2010-01-12 00:00:00 │ NULL         │
# │   566 │ 2010-01-12 00:00:00 │ NULL         │
# │   567 │ 2010-01-12 00:00:00 │ NULL         │
# │   568 │ 2010-01-12 00:00:00 │ NULL         │
# │   569 │ 2010-01-12 00:00:00 │ NULL         │
# │   570 │ 2010-01-12 00:00:00 │ NULL         │
# │   571 │ 2010-01-12 00:00:00 │ NULL         │
# │   572 │ 2010-01-12 00:00:00 │ NULL         │
# ├───────┴─────────────────────┴──────────────┤
# │ ? rows (>9999 rows, 20 shown)    3 columns │
# └────────────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %%
temporal_helper.convert_query("""
                PREDICT LIST_DISTINCT(results.position, 0, 100, days) RANK TOP 3
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT LIST_DISTINCT(results.position, 0, 100, days) RANK TOP 3
#                 FOR EACH drivers.driverId;
#
# ------PREDICT_START------
# SELECT
#     parent.driverId AS fk,
#     time.timestamp AS timestamp,
#     CASE
#         WHEN ARRAY_LENGTH(main.comp_col) > 3 THEN main.comp_col[1:3]
#         ELSE main.comp_col
#     END
#  AS label
# FROM
#     drivers parent
# CROSS JOIN
#     timestamp_df time
# LEFT JOIN
#     (------AGGREGATION_START------
#     SELECT
#         parent.driverId AS fk,
#         (
#         SELECT
#             ARRAY_AGG(freq_tbl.val ORDER BY freq_tbl.freq DESC)
#         FROM (
#             SELECT
#                 in_tbl.position AS val,
#                 COUNT(*) AS freq
#             FROM
#                 results in_tbl
#             WHERE
#                 in_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#             AND
#                 in_tbl.date <  time.timestamp + INTERVAL '100 DAY'
#             AND
#                 in_tbl.driverId = parent.driverId
#             GROUP BY in_tbl.position
#             ) freq_tbl
#         )
#      AS comp_col,
#         time.timestamp AS timestamp
#     FROM
#         drivers parent
#     CROSS JOIN
#         timestamp_df time
#     LEFT JOIN
#         results aggr_tbl
#     ON
#         aggr_tbl.driverId = parent.driverId
#     AND
#         aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#     AND
#         aggr_tbl.date < time.timestamp + INTERVAL '100 DAY'
#     GROUP BY
#         time.timestamp, parent.driverId
#     ------AGGREGATION_END------
# ) main
# ON
#     main.fk = parent.driverId
# AND
#     main.timestamp = time.timestamp
# ORDER BY
#     time.timestamp ASC, parent.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬────────────────────┐
# │  fk   │      timestamp      │       label        │
# │ int64 │    timestamp_ns     │      double[]      │
# ├───────┼─────────────────────┼────────────────────┤
# │     0 │ 2010-01-01 00:00:00 │ [6.0, 3.0]         │
# │     1 │ 2010-01-01 00:00:00 │ NULL               │
# │     2 │ 2010-01-01 00:00:00 │ [5.0, 3.0]         │
# │     3 │ 2010-01-01 00:00:00 │ [4.0, 1.0, 13.0]   │
# │     4 │ 2010-01-01 00:00:00 │ [15.0, NULL, 13.0] │
# │     5 │ 2010-01-01 00:00:00 │ NULL               │
# │     6 │ 2010-01-01 00:00:00 │ NULL               │
# │     7 │ 2010-01-01 00:00:00 │ NULL               │
# │     8 │ 2010-01-01 00:00:00 │ [2.0, 11.0, 4.0]   │
# │     9 │ 2010-01-01 00:00:00 │ [NULL]             │
# │     · │          ·          │  ·                 │
# │     · │          ·          │  ·                 │
# │     · │          ·          │  ·                 │
# │   563 │ 2010-01-12 00:00:00 │ NULL               │
# │   564 │ 2010-01-12 00:00:00 │ NULL               │
# │   565 │ 2010-01-12 00:00:00 │ NULL               │
# │   566 │ 2010-01-12 00:00:00 │ NULL               │
# │   567 │ 2010-01-12 00:00:00 │ NULL               │
# │   568 │ 2010-01-12 00:00:00 │ NULL               │
# │   569 │ 2010-01-12 00:00:00 │ NULL               │
# │   570 │ 2010-01-12 00:00:00 │ NULL               │
# │   571 │ 2010-01-12 00:00:00 │ NULL               │
# │   572 │ 2010-01-12 00:00:00 │ NULL               │
# ├───────┴─────────────────────┴────────────────────┤
# │ ? rows (>9999 rows, 20 shown)          3 columns │
# └──────────────────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %%
temporal_helper.convert_query("""
                PREDICT FIRST(results.position, 0, 100, days)
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT FIRST(results.position, 0, 100, days)
#                 FOR EACH drivers.driverId;
#
# ------PREDICT_START------
# SELECT
#     parent.driverId AS fk,
#     time.timestamp AS timestamp,
#     main.comp_col
#  AS label
# FROM
#     drivers parent
# CROSS JOIN
#     timestamp_df time
# LEFT JOIN
#     (------AGGREGATION_START------
#     SELECT
#         parent.driverId AS fk,
#         ARRAY_AGG(aggr_tbl.position ORDER BY aggr_tbl.date ASC)[1]
#      AS comp_col,
#         time.timestamp AS timestamp
#     FROM
#         drivers parent
#     CROSS JOIN
#         timestamp_df time
#     LEFT JOIN
#         results aggr_tbl
#     ON
#         aggr_tbl.driverId = parent.driverId
#     AND
#         aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#     AND
#         aggr_tbl.date < time.timestamp + INTERVAL '100 DAY'
#     GROUP BY
#         time.timestamp, parent.driverId
#     ------AGGREGATION_END------
# ) main
# ON
#     main.fk = parent.driverId
# AND
#     main.timestamp = time.timestamp
# ORDER BY
#     time.timestamp ASC, parent.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬────────┐
# │  fk   │      timestamp      │ label  │
# │ int64 │    timestamp_ns     │ double │
# ├───────┼─────────────────────┼────────┤
# │     0 │ 2010-01-01 00:00:00 │    3.0 │
# │     1 │ 2010-01-01 00:00:00 │   NULL │
# │     2 │ 2010-01-01 00:00:00 │    5.0 │
# │     3 │ 2010-01-01 00:00:00 │    1.0 │
# │     4 │ 2010-01-01 00:00:00 │   15.0 │
# │     5 │ 2010-01-01 00:00:00 │   NULL │
# │     6 │ 2010-01-01 00:00:00 │   NULL │
# │     7 │ 2010-01-01 00:00:00 │   NULL │
# │     8 │ 2010-01-01 00:00:00 │   11.0 │
# │     9 │ 2010-01-01 00:00:00 │   NULL │
# │     · │          ·          │     ·  │
# │     · │          ·          │     ·  │
# │     · │          ·          │     ·  │
# │   563 │ 2010-01-12 00:00:00 │   NULL │
# │   564 │ 2010-01-12 00:00:00 │   NULL │
# │   565 │ 2010-01-12 00:00:00 │   NULL │
# │   566 │ 2010-01-12 00:00:00 │   NULL │
# │   567 │ 2010-01-12 00:00:00 │   NULL │
# │   568 │ 2010-01-12 00:00:00 │   NULL │
# │   569 │ 2010-01-12 00:00:00 │   NULL │
# │   570 │ 2010-01-12 00:00:00 │   NULL │
# │   571 │ 2010-01-12 00:00:00 │   NULL │
# │   572 │ 2010-01-12 00:00:00 │   NULL │
# ├───────┴─────────────────────┴────────┤
# │ ? rows                     3 columns │
# │ (>9999 rows, 20 shown)               │
# └──────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %%
temporal_helper.convert_query("""
                PREDICT LIST_DISTINCT(results.position, 0, 100, days)
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT LIST_DISTINCT(results.position, 0, 100, days)
#                 FOR EACH drivers.driverId;
#
# ------PREDICT_START------
# SELECT
#     parent.driverId AS fk,
#     time.timestamp AS timestamp,
#     main.comp_col
#  AS label
# FROM
#     drivers parent
# CROSS JOIN
#     timestamp_df time
# LEFT JOIN
#     (------AGGREGATION_START------
#     SELECT
#         parent.driverId AS fk,
#         (
#         SELECT
#             ARRAY_AGG(freq_tbl.val ORDER BY freq_tbl.freq DESC)
#         FROM (
#             SELECT
#                 in_tbl.position AS val,
#                 COUNT(*) AS freq
#             FROM
#                 results in_tbl
#             WHERE
#                 in_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#             AND
#                 in_tbl.date <  time.timestamp + INTERVAL '100 DAY'
#             AND
#                 in_tbl.driverId = parent.driverId
#             GROUP BY in_tbl.position
#             ) freq_tbl
#         )
#      AS comp_col,
#         time.timestamp AS timestamp
#     FROM
#         drivers parent
#     CROSS JOIN
#         timestamp_df time
#     LEFT JOIN
#         results aggr_tbl
#     ON
#         aggr_tbl.driverId = parent.driverId
#     AND
#         aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#     AND
#         aggr_tbl.date < time.timestamp + INTERVAL '100 DAY'
#     GROUP BY
#         time.timestamp, parent.driverId
#     ------AGGREGATION_END------
# ) main
# ON
#     main.fk = parent.driverId
# AND
#     main.timestamp = time.timestamp
# ORDER BY
#     time.timestamp ASC, parent.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬────────────────────┐
# │  fk   │      timestamp      │       label        │
# │ int64 │    timestamp_ns     │      double[]      │
# ├───────┼─────────────────────┼────────────────────┤
# │     0 │ 2010-01-01 00:00:00 │ [6.0, 3.0]         │
# │     1 │ 2010-01-01 00:00:00 │ NULL               │
# │     2 │ 2010-01-01 00:00:00 │ [5.0, 3.0]         │
# │     3 │ 2010-01-01 00:00:00 │ [4.0, 1.0, 13.0]   │
# │     4 │ 2010-01-01 00:00:00 │ [15.0, NULL, 13.0] │
# │     5 │ 2010-01-01 00:00:00 │ NULL               │
# │     6 │ 2010-01-01 00:00:00 │ NULL               │
# │     7 │ 2010-01-01 00:00:00 │ NULL               │
# │     8 │ 2010-01-01 00:00:00 │ [11.0, 4.0, 2.0]   │
# │     9 │ 2010-01-01 00:00:00 │ [NULL]             │
# │     · │          ·          │  ·                 │
# │     · │          ·          │  ·                 │
# │     · │          ·          │  ·                 │
# │   563 │ 2010-01-12 00:00:00 │ NULL               │
# │   564 │ 2010-01-12 00:00:00 │ NULL               │
# │   565 │ 2010-01-12 00:00:00 │ NULL               │
# │   566 │ 2010-01-12 00:00:00 │ NULL               │
# │   567 │ 2010-01-12 00:00:00 │ NULL               │
# │   568 │ 2010-01-12 00:00:00 │ NULL               │
# │   569 │ 2010-01-12 00:00:00 │ NULL               │
# │   570 │ 2010-01-12 00:00:00 │ NULL               │
# │   571 │ 2010-01-12 00:00:00 │ NULL               │
# │   572 │ 2010-01-12 00:00:00 │ NULL               │
# ├───────┴─────────────────────┴────────────────────┤
# │ ? rows (>9999 rows, 20 shown)          3 columns │
# └──────────────────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %%
temporal_helper.convert_query("""
                PREDICT COUNT(results.position, 0, 100, days)
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT COUNT(results.position, 0, 100, days)
#                 FOR EACH drivers.driverId;
#
# ------PREDICT_START------
# SELECT
#     parent.driverId AS fk,
#     time.timestamp AS timestamp,
#     main.comp_col
#  AS label
# FROM
#     drivers parent
# CROSS JOIN
#     timestamp_df time
# LEFT JOIN
#     (------AGGREGATION_START------
#     SELECT
#         parent.driverId AS fk,
#         COUNT(aggr_tbl.position)
#      AS comp_col,
#         time.timestamp AS timestamp
#     FROM
#         drivers parent
#     CROSS JOIN
#         timestamp_df time
#     LEFT JOIN
#         results aggr_tbl
#     ON
#         aggr_tbl.driverId = parent.driverId
#     AND
#         aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#     AND
#         aggr_tbl.date < time.timestamp + INTERVAL '100 DAY'
#     GROUP BY
#         time.timestamp, parent.driverId
#     ------AGGREGATION_END------
# ) main
# ON
#     main.fk = parent.driverId
# AND
#     main.timestamp = time.timestamp
# ORDER BY
#     time.timestamp ASC, parent.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬───────┐
# │  fk   │      timestamp      │ label │
# │ int64 │    timestamp_ns     │ int64 │
# ├───────┼─────────────────────┼───────┤
# │     0 │ 2010-01-01 00:00:00 │     3 │
# │     1 │ 2010-01-01 00:00:00 │     0 │
# │     2 │ 2010-01-01 00:00:00 │     3 │
# │     3 │ 2010-01-01 00:00:00 │     3 │
# │     4 │ 2010-01-01 00:00:00 │     2 │
# │     5 │ 2010-01-01 00:00:00 │     0 │
# │     6 │ 2010-01-01 00:00:00 │     0 │
# │     7 │ 2010-01-01 00:00:00 │     0 │
# │     8 │ 2010-01-01 00:00:00 │     3 │
# │     9 │ 2010-01-01 00:00:00 │     0 │
# │     · │          ·          │     · │
# │     · │          ·          │     · │
# │     · │          ·          │     · │
# │   563 │ 2010-01-12 00:00:00 │     0 │
# │   564 │ 2010-01-12 00:00:00 │     0 │
# │   565 │ 2010-01-12 00:00:00 │     0 │
# │   566 │ 2010-01-12 00:00:00 │     0 │
# │   567 │ 2010-01-12 00:00:00 │     0 │
# │   568 │ 2010-01-12 00:00:00 │     0 │
# │   569 │ 2010-01-12 00:00:00 │     0 │
# │   570 │ 2010-01-12 00:00:00 │     0 │
# │   571 │ 2010-01-12 00:00:00 │     0 │
# │   572 │ 2010-01-12 00:00:00 │     0 │
# ├───────┴─────────────────────┴───────┤
# │ ? rows                    3 columns │
# │ (>9999 rows, 20 shown)              │
# └─────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %%
temporal_helper.convert_query("""
                PREDICT AVG(results.position WHERE drivers.driverId < 10, 0, 100, days)
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT AVG(results.position WHERE drivers.driverId < 10, 0, 100, days)
#                 FOR EACH drivers.driverId;
#
# SELECT
#     sq.fk,
#     sq.timestamp,
#     sq.label
# FROM
#     (------PREDICT_START------
#     SELECT
#         parent.driverId AS fk,
#         time.timestamp AS timestamp,
#         main.comp_col
#      AS label
#     FROM
#         drivers parent
#     CROSS JOIN
#         timestamp_df time
#     LEFT JOIN
#         (------AGGREGATION_START------
#         SELECT
#             parent.driverId AS fk,
#             AVG(aggr_tbl.position)
#          AS comp_col,
#             time.timestamp AS timestamp
#         FROM
#             drivers parent
#         CROSS JOIN
#             timestamp_df time
#         LEFT JOIN
#             results aggr_tbl
#         ON
#             aggr_tbl.driverId = parent.driverId
#         AND
#             aggr_tbl.date >= time.timestamp + INTERVAL '0 DAY'
#         AND
#             aggr_tbl.date < time.timestamp + INTERVAL '100 DAY'
#         GROUP BY
#             time.timestamp, parent.driverId
#         ------AGGREGATION_END------
#     ) main
#     ON
#         main.fk = parent.driverId
#     AND
#         main.timestamp = time.timestamp
#     ORDER BY
#         time.timestamp ASC, parent.driverId ASC
#     ------PREDICT_END------
# ) sq
# JOIN
#     (------CONDITION_START------
#     SELECT
#         *
#     FROM
#         (------ID_DOT_ID_START------
#         SELECT
#             driverId AS fk,
#             driverId AS comp_col
#         FROM
#             drivers
#         ------ID_DOT_ID_END------
#     )
#     WHERE
#         comp_col < 10
#     ------CONDITION_END------
# ) hq
# ON
#     hq.fk = sq.fk
# ORDER BY
#     sq.timestamp ASC, sq.fk ASC
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬────────────────────┐
# │  fk   │      timestamp      │       label        │
# │ int64 │    timestamp_ns     │       double       │
# ├───────┼─────────────────────┼────────────────────┤
# │     0 │ 2010-01-01 00:00:00 │                5.0 │
# │     1 │ 2010-01-01 00:00:00 │               NULL │
# │     2 │ 2010-01-01 00:00:00 │  4.333333333333333 │
# │     3 │ 2010-01-01 00:00:00 │                6.0 │
# │     4 │ 2010-01-01 00:00:00 │               14.0 │
# │     5 │ 2010-01-01 00:00:00 │               NULL │
# │     6 │ 2010-01-01 00:00:00 │               NULL │
# │     7 │ 2010-01-01 00:00:00 │               NULL │
# │     8 │ 2010-01-01 00:00:00 │  5.666666666666667 │
# │     9 │ 2010-01-01 00:00:00 │               NULL │
# │     · │          ·          │                 ·  │
# │     · │          ·          │                 ·  │
# │     · │          ·          │                 ·  │
# │     0 │ 2010-05-05 00:00:00 │  4.142857142857143 │
# │     1 │ 2010-05-05 00:00:00 │               NULL │
# │     2 │ 2010-05-05 00:00:00 │  7.428571428571429 │
# │     3 │ 2010-05-05 00:00:00 │                5.5 │
# │     4 │ 2010-05-05 00:00:00 │ 15.666666666666666 │
# │     5 │ 2010-05-05 00:00:00 │               NULL │
# │     6 │ 2010-05-05 00:00:00 │               NULL │
# │     7 │ 2010-05-05 00:00:00 │               NULL │
# │     8 │ 2010-05-05 00:00:00 │                6.0 │
# │     9 │ 2010-05-05 00:00:00 │ 17.833333333333332 │
# ├───────┴─────────────────────┴────────────────────┤
# │ 1250 rows (20 shown)                   3 columns │
# └──────────────────────────────────────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: timestamp
# -------------------------------------------
# ========================================

# %% [markdown]
# #### STATIC

# %%
f1_dataset = F1Dataset()
db = f1_dataset.get_db(upto_test_timestamp=False)
static_helper = ConverterShowcaseHelper(db, timestamps=None)
# Out:
# Making Database object from scratch...
# (You can also use `get_dataset(..., download=True)` for datasets prepared by the RelBench team.)
# Done in 0.17 seconds.

# %%
print(db.table_dict["drivers"])
# Out:
# Table(df=
#      driverId        driverRef code  forename     surname        dob  \
# 0           0         hamilton  HAM     Lewis    Hamilton 1985-01-07
# 1           1         heidfeld  HEI      Nick    Heidfeld 1977-05-10
# 2           2          rosberg  ROS      Nico     Rosberg 1985-06-27
# 3           3           alonso  ALO  Fernando      Alonso 1981-07-29
# 4           4       kovalainen  KOV    Heikki  Kovalainen 1981-10-19
# ..        ...              ...  ...       ...         ...        ...
# 852       852  mick_schumacher  MSC      Mick  Schumacher 1999-03-22
# 853       853             zhou  ZHO    Guanyu        Zhou 1999-05-30
# 854       854         de_vries  DEV      Nyck    de Vries 1995-02-06
# 855       855          piastri  PIA     Oscar     Piastri 2001-04-06
# 856       856         sargeant  SAR     Logan    Sargeant 2000-12-31
#
#     nationality
# 0       British
# 1        German
# 2        German
# 3       Spanish
# 4       Finnish
# ..          ...
# 852      German
# 853     Chinese
# 854       Dutch
# 855  Australian
# 856    American
#
# [857 rows x 7 columns],
#   fkey_col_to_pkey_table={},
#   pkey_col=driverId,
#   time_col=None)

# %%
static_helper.convert_query("""
                PREDICT drivers.surname CONTAINS "l"
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT drivers.surname CONTAINS "l"
#                 FOR EACH drivers.driverId;
#
# ------PREDICT_START------
# SELECT
#     parent.driverId AS fk,
#     CASE
#         WHEN main.fk IS NOT NULL THEN TRUE
#         ELSE FALSE
#     END
#  AS label
# FROM
#     drivers parent
# LEFT JOIN
#     (------CONDITION_START------
#     SELECT
#         *
#     FROM
#         (------ID_DOT_ID_START------
#         SELECT
#             driverId AS fk,
#             surname AS comp_col
#         FROM
#             drivers
#         ------ID_DOT_ID_END------
#     )
#     WHERE
#         comp_col LIKE '%l%'
#     ------CONDITION_END------
# ) main
# ON
#     main.fk = parent.driverId
# ORDER BY
#     parent.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────┐
# │  fk   │  label  │
# │ int64 │ boolean │
# ├───────┼─────────┤
# │     0 │ true    │
# │     1 │ true    │
# │     2 │ false   │
# │     3 │ true    │
# │     4 │ true    │
# │     5 │ false   │
# │     6 │ false   │
# │     7 │ false   │
# │     8 │ false   │
# │     9 │ true    │
# │     · │  ·      │
# │     · │  ·      │
# │     · │  ·      │
# │   847 │ false   │
# │   848 │ true    │
# │   849 │ false   │
# │   850 │ false   │
# │   851 │ false   │
# │   852 │ false   │
# │   853 │ false   │
# │   854 │ false   │
# │   855 │ false   │
# │   856 │ false   │
# ├───────┴─────────┤
# │    857 rows     │
# │   (20 shown)    │
# └─────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: None
# -------------------------------------------
# ========================================

# %%
static_helper.convert_query("""
                PREDICT drivers.driverId < 10
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT drivers.driverId < 10
#                 FOR EACH drivers.driverId;
#
# ------PREDICT_START------
# SELECT
#     parent.driverId AS fk,
#     CASE
#         WHEN main.fk IS NOT NULL THEN TRUE
#         ELSE FALSE
#     END
#  AS label
# FROM
#     drivers parent
# LEFT JOIN
#     (------CONDITION_START------
#     SELECT
#         *
#     FROM
#         (------ID_DOT_ID_START------
#         SELECT
#             driverId AS fk,
#             driverId AS comp_col
#         FROM
#             drivers
#         ------ID_DOT_ID_END------
#     )
#     WHERE
#         comp_col < 10
#     ------CONDITION_END------
# ) main
# ON
#     main.fk = parent.driverId
# ORDER BY
#     parent.driverId ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────┐
# │  fk   │  label  │
# │ int64 │ boolean │
# ├───────┼─────────┤
# │     0 │ true    │
# │     1 │ true    │
# │     2 │ true    │
# │     3 │ true    │
# │     4 │ true    │
# │     5 │ true    │
# │     6 │ true    │
# │     7 │ true    │
# │     8 │ true    │
# │     9 │ true    │
# │     · │  ·      │
# │     · │  ·      │
# │     · │  ·      │
# │   847 │ false   │
# │   848 │ false   │
# │   849 │ false   │
# │   850 │ false   │
# │   851 │ false   │
# │   852 │ false   │
# │   853 │ false   │
# │   854 │ false   │
# │   855 │ false   │
# │   856 │ false   │
# ├───────┴─────────┤
# │    857 rows     │
# │   (20 shown)    │
# └─────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: None
# -------------------------------------------
# ========================================

# %%
static_helper.convert_query("""
                PREDICT drivers.driverId < 10
                FOR EACH drivers.driverId
                WHERE drivers.driverId > 5;
              """)
# Out:
# ========================================
#
#                 PREDICT drivers.driverId < 10
#                 FOR EACH drivers.driverId
#                 WHERE drivers.driverId > 5;
#
# ------PREDICT_START------
# SELECT
#     for_each.fk AS fk,
#     CASE
#         WHEN main.fk IS NOT NULL THEN TRUE
#         ELSE FALSE
#     END
#  AS label
# FROM
#     (------CONDITION_START------
#     SELECT
#         *
#     FROM
#         (------ID_DOT_ID_START------
#         SELECT
#             driverId AS fk,
#             driverId AS comp_col
#         FROM
#             drivers
#         ------ID_DOT_ID_END------
#     )
#     WHERE
#         comp_col > 5
#     ------CONDITION_END------
# ) for_each
# LEFT JOIN
#     (------CONDITION_START------
#     SELECT
#         *
#     FROM
#         (------ID_DOT_ID_START------
#         SELECT
#             driverId AS fk,
#             driverId AS comp_col
#         FROM
#             drivers
#         ------ID_DOT_ID_END------
#     )
#     WHERE
#         comp_col < 10
#     ------CONDITION_END------
# ) main
# ON
#     main.fk = for_each.fk
# ORDER BY
#     main.fk ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────┐
# │  fk   │  label  │
# │ int64 │ boolean │
# ├───────┼─────────┤
# │     6 │ true    │
# │     7 │ true    │
# │     8 │ true    │
# │     9 │ true    │
# │    10 │ false   │
# │    11 │ false   │
# │    12 │ false   │
# │    13 │ false   │
# │    14 │ false   │
# │    15 │ false   │
# │     · │   ·     │
# │     · │   ·     │
# │     · │   ·     │
# │   847 │ false   │
# │   848 │ false   │
# │   849 │ false   │
# │   850 │ false   │
# │   851 │ false   │
# │   852 │ false   │
# │   853 │ false   │
# │   854 │ false   │
# │   855 │ false   │
# │   856 │ false   │
# ├───────┴─────────┤
# │    851 rows     │
# │   (20 shown)    │
# └─────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: None
# -------------------------------------------
# ========================================

# %%
static_helper.convert_query("""
                PREDICT NOT drivers.driverId > 5
                FOR EACH drivers.driverId
                WHERE drivers.driverId > 10;
              """)
# Out:
# ========================================
#
#                 PREDICT NOT drivers.driverId > 5
#                 FOR EACH drivers.driverId
#                 WHERE drivers.driverId > 10;
#
# ------PREDICT_START------
# SELECT
#     for_each.fk AS fk,
#     CASE
#         WHEN main.fk IS NOT NULL THEN TRUE
#         ELSE FALSE
#     END
#  AS label
# FROM
#     (------CONDITION_START------
#     SELECT
#         *
#     FROM
#         (------ID_DOT_ID_START------
#         SELECT
#             driverId AS fk,
#             driverId AS comp_col
#         FROM
#             drivers
#         ------ID_DOT_ID_END------
#     )
#     WHERE
#         comp_col > 10
#     ------CONDITION_END------
# ) for_each
# LEFT JOIN
#     (------CONDITION_START------
#     SELECT
#         *
#     FROM
#         (------ID_DOT_ID_START------
#         SELECT
#             driverId AS fk,
#             driverId AS comp_col
#         FROM
#             drivers
#         ------ID_DOT_ID_END------
#     )
#     WHERE
#         NOT comp_col > 5
#     ------CONDITION_END------
# ) main
# ON
#     main.fk = for_each.fk
# ORDER BY
#     main.fk ASC
# ------PREDICT_END------
# ;
# ------------------ Table ------------------
# DataFrame:
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────┐
# │  fk   │  label  │
# │ int64 │ boolean │
# ├───────┼─────────┤
# │    11 │ false   │
# │    12 │ false   │
# │    13 │ false   │
# │    14 │ false   │
# │    15 │ false   │
# │    16 │ false   │
# │    17 │ false   │
# │    18 │ false   │
# │    19 │ false   │
# │    20 │ false   │
# │     · │   ·     │
# │     · │   ·     │
# │     · │   ·     │
# │   847 │ false   │
# │   848 │ false   │
# │   849 │ false   │
# │   850 │ false   │
# │   851 │ false   │
# │   852 │ false   │
# │   853 │ false   │
# │   854 │ false   │
# │   855 │ false   │
# │   856 │ false   │
# ├───────┴─────────┤
# │    846 rows     │
# │   (20 shown)    │
# └─────────────────┘
# >
# Foreign Key Columns to Primary Key Tables: None
# Primary Key Column: None
# Time Column: None
# -------------------------------------------
# ========================================
