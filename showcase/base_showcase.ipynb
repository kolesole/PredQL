# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append("..")

from relbench.datasets.f1 import F1Dataset

from predql.base import Database, Table

# %%
f1_dataset = F1Dataset()
db = f1_dataset.get_db(upto_test_timestamp=False)
# Out:
# Making Database object from scratch...
# (You can also use `get_dataset(..., download=True)` for datasets prepared by the RelBench team.)
# Done in 0.21 seconds.

# %%
db = Database(table_dict=db.table_dict)

# %%
print(db)
# Out:
# ================= Database ================
# Table Name: races
# Table(df=
#       raceId  year  ...                date      time
# 0          0  1950  ... 1950-05-13 00:00:00  00:00:00
# 1          1  1950  ... 1950-05-21 00:00:00  00:00:00
# 2          2  1950  ... 1950-05-30 00:00:00  00:00:00
# 3          3  1950  ... 1950-06-04 00:00:00  00:00:00
# 4          4  1950  ... 1950-06-18 00:00:00  00:00:00
# ...      ...   ...  ...                 ...       ...
# 1096    1096  2023  ... 2023-10-22 19:00:00  19:00:00
# 1097    1097  2023  ... 2023-10-29 20:00:00  20:00:00
# 1098    1098  2023  ... 2023-11-05 17:00:00  17:00:00
# 1099    1099  2023  ... 2023-11-19 06:00:00  06:00:00
# 1100    1100  2023  ... 2023-11-26 13:00:00  13:00:00
#
# [1101 rows x 7 columns],
#   fkey_col_to_pkey_table={'circuitId': 'circuits'},
#   pkey_col=raceId,
#   time_col=date)
# Table Name: circuits
# Table(df=
#     circuitId   circuitRef  ...        lng    alt
# 0           0  albert_park  ...  144.96800   10.0
# 1           1       sepang  ...  101.73800   18.0
# 2           2      bahrain  ...   50.51060    7.0
# 3           3    catalunya  ...    2.26111  109.0
# 4           4     istanbul  ...   29.40500  130.0
# ..        ...          ...  ...        ...    ...
# 72         72     portimao  ...   -8.62670  108.0
# 73         73      mugello  ...   11.37190  255.0
# 74         74       jeddah  ...   39.10440   15.0
# 75         75       losail  ...   51.45420    NaN
# 76         76        miami  ...  -80.23890    NaN
#
# [77 rows x 8 columns],
#   fkey_col_to_pkey_table={},
#   pkey_col=circuitId,
#   time_col=None)
# Table Name: drivers
# Table(df=
#      driverId        driverRef code  ...     surname        dob nationality
# 0           0         hamilton  HAM  ...    Hamilton 1985-01-07     British
# 1           1         heidfeld  HEI  ...    Heidfeld 1977-05-10      German
# 2           2          rosberg  ROS  ...     Rosberg 1985-06-27      German
# 3           3           alonso  ALO  ...      Alonso 1981-07-29     Spanish
# 4           4       kovalainen  KOV  ...  Kovalainen 1981-10-19     Finnish
# ..        ...              ...  ...  ...         ...        ...         ...
# 852       852  mick_schumacher  MSC  ...  Schumacher 1999-03-22      German
# 853       853             zhou  ZHO  ...        Zhou 1999-05-30     Chinese
# 854       854         de_vries  DEV  ...    de Vries 1995-02-06       Dutch
# 855       855          piastri  PIA  ...     Piastri 2001-04-06  Australian
# 856       856         sargeant  SAR  ...    Sargeant 2000-12-31    American
#
# [857 rows x 7 columns],
#   fkey_col_to_pkey_table={},
#   pkey_col=driverId,
#   time_col=None)
# Table Name: results
# Table(df=
#        resultId  raceId  driverId  ...  rank  statusId                date
# 0             0       0       660  ...   NaN        16 1950-05-13 00:00:00
# 1             1       0       790  ...   NaN       126 1950-05-13 00:00:00
# 2             2       0       579  ...   NaN        44 1950-05-13 00:00:00
# 3             3       0       661  ...   NaN         6 1950-05-13 00:00:00
# 4             4       0       789  ...   NaN        51 1950-05-13 00:00:00
# ...         ...     ...       ...  ...   ...       ...                 ...
# 26075     26075    1090       814  ...   6.0         1 2023-07-30 13:00:00
# 26076     26076    1090       829  ...   2.0         1 2023-07-30 13:00:00
# 26077     26077    1090       831  ...  19.0       130 2023-07-30 13:00:00
# 26078     26078    1090       839  ...  16.0         1 2023-07-30 13:00:00
# 26079     26079    1090       855  ...   0.0       130 2023-07-30 13:00:00
#
# [26080 rows x 15 columns],
#   fkey_col_to_pkey_table={'raceId': 'races', 'driverId': 'drivers', 'constructorId': 'constructors'},
#   pkey_col=resultId,
#   time_col=date)
# Table Name: standings
# Table(df=
#        driverStandingsId  raceId  driverId  ...  position  wins                date
# 0                      0       0       789  ...        20     0 1950-05-13 00:00:00
# 1                      1       0       640  ...        18     0 1950-05-13 00:00:00
# 2                      2       0       589  ...        19     0 1950-05-13 00:00:00
# 3                      3       0       669  ...        15     0 1950-05-13 00:00:00
# 4                      4       0       661  ...        22     0 1950-05-13 00:00:00
# ...                  ...     ...       ...  ...       ...   ...                 ...
# 34119              34119    1090       814  ...         2     2 2023-07-30 13:00:00
# 34120              34120    1090       829  ...         1    10 2023-07-30 13:00:00
# 34121              34121    1090       855  ...        11     0 2023-07-30 13:00:00
# 34122              34122    1090       846  ...        13     0 2023-07-30 13:00:00
# 34123              34123    1090       816  ...        21     0 2023-07-30 13:00:00
#
# [34124 rows x 7 columns],
#   fkey_col_to_pkey_table={'raceId': 'races', 'driverId': 'drivers'},
#   pkey_col=driverStandingsId,
#   time_col=date)
# Table Name: constructors
# Table(df=
#      constructorId constructorRef            name nationality
# 0                0        mclaren         McLaren     British
# 1                1     bmw_sauber      BMW Sauber      German
# 2                2       williams        Williams     British
# 3                3        renault         Renault      French
# 4                4     toro_rosso      Toro Rosso     Italian
# ..             ...            ...             ...         ...
# 206            206          manor  Manor Marussia     British
# 207            207           haas    Haas F1 Team    American
# 208            208   racing_point    Racing Point     British
# 209            209     alphatauri      AlphaTauri     Italian
# 210            210         alpine  Alpine F1 Team      French
#
# [211 rows x 4 columns],
#   fkey_col_to_pkey_table={},
#   pkey_col=constructorId,
#   time_col=None)
# Table Name: constructor_results
# Table(df=
#        constructorResultsId  raceId  constructorId  points                date
# 0                         0      48            103    13.0 1956-01-22 00:00:00
# 1                         1      48              5    12.0 1956-01-22 00:00:00
# 2                         2      54            126     0.0 1956-08-05 00:00:00
# 3                         3      54            103    15.0 1956-08-05 00:00:00
# 4                         4      54              5     9.0 1956-08-05 00:00:00
# ...                     ...     ...            ...     ...                 ...
# 12285                 12285    1090              0    16.0 2023-07-30 13:00:00
# 12286                 12286    1090            210    10.0 2023-07-30 13:00:00
# 12287                 12287    1090            209     1.0 2023-07-30 13:00:00
# 12288                 12288    1090             49     0.0 2023-07-30 13:00:00
# 12289                 12289    1090            207     0.0 2023-07-30 13:00:00
#
# [12290 rows x 5 columns],
#   fkey_col_to_pkey_table={'raceId': 'races', 'constructorId': 'constructors'},
#   pkey_col=constructorResultsId,
#   time_col=date)
# Table Name: constructor_standings
# Table(df=
#        constructorStandingsId  raceId  ...  wins                date
# 0                           0      64  ...     0 1958-01-19 00:00:00
# 1                           1      64  ...     0 1958-01-19 00:00:00
# 2                           2      64  ...     1 1958-01-19 00:00:00
# 3                           3      65  ...     2 1958-05-18 00:00:00
# 4                           4      65  ...     0 1958-05-18 00:00:00
# ...                       ...     ...  ...   ...                 ...
# 13046                   13046    1090  ...     0 2023-07-30 13:00:00
# 13047                   13047    1090  ...     0 2023-07-30 13:00:00
# 13048                   13048    1090  ...     0 2023-07-30 13:00:00
# 13049                   13049    1090  ...     0 2023-07-30 13:00:00
# 13050                   13050    1090  ...     0 2023-07-30 13:00:00
#
# [13051 rows x 7 columns],
#   fkey_col_to_pkey_table={'raceId': 'races', 'constructorId': 'constructors'},
#   pkey_col=constructorStandingsId,
#   time_col=date)
# Table Name: qualifying
# Table(df=
#       qualifyId  raceId  driverId  ...  number  position                date
# 0             0     548        43  ...      26        19 1994-03-26 00:00:00
# 1             1     548       100  ...      31        26 1994-03-26 00:00:00
# 2             2     548        91  ...      34        25 1994-03-26 00:00:00
# 3             3     548        82  ...      11        24 1994-03-26 00:00:00
# 4             4     548       105  ...      19        23 1994-03-26 00:00:00
# ...         ...     ...       ...  ...     ...       ...                 ...
# 9810       9810    1090       842  ...      16         2 2023-07-29 13:00:00
# 9811       9811    1090       829  ...       1         1 2023-07-29 13:00:00
# 9812       9812    1090       816  ...       3        19 2023-07-29 13:00:00
# 9813       9813    1090         3  ...      14         9 2023-07-29 13:00:00
# 9814       9814    1090       807  ...      27        20 2023-07-29 13:00:00
#
# [9815 rows x 7 columns],
#   fkey_col_to_pkey_table={'raceId': 'races', 'driverId': 'drivers', 'constructorId': 'constructors'},
#   pkey_col=qualifyId,
#   time_col=date)
