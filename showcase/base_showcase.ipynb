# %%
# %load_ext autoreload
# %autoreload 2

# %%
from relbench.datasets.f1 import F1Dataset

from predql.base import Database

# %%
f1_dataset = F1Dataset()
db = f1_dataset.get_db(upto_test_timestamp=False)
# Out:
# Making Database object from scratch...
# (You can also use `get_dataset(..., download=True)` for datasets prepared by the RelBench team.)
# Done in 0.32 seconds.

# %%
db = Database(table_dict=db.table_dict)

# %%
print(db)
# Out:
# ================= Database ================
# Table Name: races
# Table(df=
#       raceId  year  round  circuitId                      name  \
# 0          0  1950      1          8        British Grand Prix
# 1          1  1950      2          5         Monaco Grand Prix
# 2          2  1950      3         18          Indianapolis 500
# 3          3  1950      4         65          Swiss Grand Prix
# 4          4  1950      5         12        Belgian Grand Prix
# ...      ...   ...    ...        ...                       ...
# 1096    1096  2023     18         68  United States Grand Prix
# 1097    1097  2023     19         31    Mexico City Grand Prix
# 1098    1098  2023     20         17      São Paulo Grand Prix
# 1099    1099  2023     21         22      Las Vegas Grand Prix
# 1100    1100  2023     22         23      Abu Dhabi Grand Prix
#
#                     date      time
# 0    1950-05-13 00:00:00  00:00:00
# 1    1950-05-21 00:00:00  00:00:00
# 2    1950-05-30 00:00:00  00:00:00
# 3    1950-06-04 00:00:00  00:00:00
# 4    1950-06-18 00:00:00  00:00:00
# ...                  ...       ...
# 1096 2023-10-22 19:00:00  19:00:00
# 1097 2023-10-29 20:00:00  20:00:00
# 1098 2023-11-05 17:00:00  17:00:00
# 1099 2023-11-19 06:00:00  06:00:00
# 1100 2023-11-26 13:00:00  13:00:00
#
# [1101 rows x 7 columns],
#   fkey_col_to_pkey_table={'circuitId': 'circuits'},
#   pkey_col=raceId,
#   time_col=date)
# Table Name: circuits
# Table(df=
#     circuitId   circuitRef                                  name  \
# 0           0  albert_park        Albert Park Grand Prix Circuit
# 1           1       sepang          Sepang International Circuit
# 2           2      bahrain         Bahrain International Circuit
# 3           3    catalunya        Circuit de Barcelona-Catalunya
# 4           4     istanbul                         Istanbul Park
# ..        ...          ...                                   ...
# 72         72     portimao    Autódromo Internacional do Algarve
# 73         73      mugello  Autodromo Internazionale del Mugello
# 74         74       jeddah               Jeddah Corniche Circuit
# 75         75       losail          Losail International Circuit
# 76         76        miami         Miami International Autodrome
#
#         location       country       lat        lng    alt
# 0      Melbourne     Australia -37.84970  144.96800   10.0
# 1   Kuala Lumpur      Malaysia   2.76083  101.73800   18.0
# 2         Sakhir       Bahrain  26.03250   50.51060    7.0
# 3       Montmeló         Spain  41.57000    2.26111  109.0
# 4       Istanbul        Turkey  40.95170   29.40500  130.0
# ..           ...           ...       ...        ...    ...
# 72      Portimão      Portugal  37.22700   -8.62670  108.0
# 73       Mugello         Italy  43.99750   11.37190  255.0
# 74        Jeddah  Saudi Arabia  21.63190   39.10440   15.0
# 75     Al Daayen         Qatar  25.49000   51.45420    NaN
# 76         Miami           USA  25.95810  -80.23890    NaN
#
# [77 rows x 8 columns],
#   fkey_col_to_pkey_table={},
#   pkey_col=circuitId,
#   time_col=None)
# Table Name: drivers
# Table(df=
#      driverId        driverRef code  forename     surname        dob  \
# 0           0         hamilton  HAM     Lewis    Hamilton 1985-01-07
# 1           1         heidfeld  HEI      Nick    Heidfeld 1977-05-10
# 2           2          rosberg  ROS      Nico     Rosberg 1985-06-27
# 3           3           alonso  ALO  Fernando      Alonso 1981-07-29
# 4           4       kovalainen  KOV    Heikki  Kovalainen 1981-10-19
# ..        ...              ...  ...       ...         ...        ...
# 852       852  mick_schumacher  MSC      Mick  Schumacher 1999-03-22
# 853       853             zhou  ZHO    Guanyu        Zhou 1999-05-30
# 854       854         de_vries  DEV      Nyck    de Vries 1995-02-06
# 855       855          piastri  PIA     Oscar     Piastri 2001-04-06
# 856       856         sargeant  SAR     Logan    Sargeant 2000-12-31
#
#     nationality
# 0       British
# 1        German
# 2        German
# 3       Spanish
# 4       Finnish
# ..          ...
# 852      German
# 853     Chinese
# 854       Dutch
# 855  Australian
# 856    American
#
# [857 rows x 7 columns],
#   fkey_col_to_pkey_table={},
#   pkey_col=driverId,
#   time_col=None)
# Table Name: results
# Table(df=
#        resultId  raceId  driverId  constructorId  number  grid  position  \
# 0             0       0       660            152    18.0    21      11.0
# 1             1       0       790            149     8.0    12       NaN
# 2             2       0       579             49     1.0     3       NaN
# 3             3       0       661            149     9.0    10       NaN
# 4             4       0       789            152    17.0     7       NaN
# ...         ...     ...       ...            ...     ...   ...       ...
# 26075     26075    1090       814              8    11.0     2       2.0
# 26076     26076    1090       829              8     1.0     6       1.0
# 26077     26077    1090       831              5    55.0     4       NaN
# 26078     26078    1090       839            115    18.0    10       9.0
# 26079     26079    1090       855              0    81.0     5       NaN
#
#        positionOrder  points  laps  milliseconds  fastestLap  rank  statusId  \
# 0                 11     0.0    64           NaN         NaN   NaN        16
# 1                 21     0.0     2           NaN         NaN   NaN       126
# 2                 12     0.0    62           NaN         NaN   NaN        44
# 3                 20     0.0     5           NaN         NaN   NaN         6
# 4                 19     0.0     8           NaN         NaN   NaN        51
# ...              ...     ...   ...           ...         ...   ...       ...
# 26075              2    18.0    44     4972755.0        31.0   6.0         1
# 26076              1    25.0    44     4950450.0        32.0   2.0         1
# 26077             19     0.0    23           NaN         9.0  19.0       130
# 26078              9     2.0    44     5029790.0        26.0  16.0         1
# 26079             20     0.0     0           NaN         NaN   0.0       130
#
#                      date
# 0     1950-05-13 00:00:00
# 1     1950-05-13 00:00:00
# 2     1950-05-13 00:00:00
# 3     1950-05-13 00:00:00
# 4     1950-05-13 00:00:00
# ...                   ...
# 26075 2023-07-30 13:00:00
# 26076 2023-07-30 13:00:00
# 26077 2023-07-30 13:00:00
# 26078 2023-07-30 13:00:00
# 26079 2023-07-30 13:00:00
#
# [26080 rows x 15 columns],
#   fkey_col_to_pkey_table={'raceId': 'races', 'driverId': 'drivers', 'constructorId': 'constructors'},
#   pkey_col=resultId,
#   time_col=date)
# Table Name: standings
# Table(df=
#        driverStandingsId  raceId  driverId  points  position  wins  \
# 0                      0       0       789     0.0        20     0
# 1                      1       0       640     0.0        18     0
# 2                      2       0       589     0.0        19     0
# 3                      3       0       669     0.0        15     0
# 4                      4       0       661     0.0        22     0
# ...                  ...     ...       ...     ...       ...   ...
# 34119              34119    1090       814   189.0         2     2
# 34120              34120    1090       829   314.0         1    10
# 34121              34121    1090       855    34.0        11     0
# 34122              34122    1090       846    11.0        13     0
# 34123              34123    1090       816     0.0        21     0
#
#                      date
# 0     1950-05-13 00:00:00
# 1     1950-05-13 00:00:00
# 2     1950-05-13 00:00:00
# 3     1950-05-13 00:00:00
# 4     1950-05-13 00:00:00
# ...                   ...
# 34119 2023-07-30 13:00:00
# 34120 2023-07-30 13:00:00
# 34121 2023-07-30 13:00:00
# 34122 2023-07-30 13:00:00
# 34123 2023-07-30 13:00:00
#
# [34124 rows x 7 columns],
#   fkey_col_to_pkey_table={'raceId': 'races', 'driverId': 'drivers'},
#   pkey_col=driverStandingsId,
#   time_col=date)
# Table Name: constructors
# Table(df=
#      constructorId constructorRef            name nationality
# 0                0        mclaren         McLaren     British
# 1                1     bmw_sauber      BMW Sauber      German
# 2                2       williams        Williams     British
# 3                3        renault         Renault      French
# 4                4     toro_rosso      Toro Rosso     Italian
# ..             ...            ...             ...         ...
# 206            206          manor  Manor Marussia     British
# 207            207           haas    Haas F1 Team    American
# 208            208   racing_point    Racing Point     British
# 209            209     alphatauri      AlphaTauri     Italian
# 210            210         alpine  Alpine F1 Team      French
#
# [211 rows x 4 columns],
#   fkey_col_to_pkey_table={},
#   pkey_col=constructorId,
#   time_col=None)
# Table Name: constructor_results
# Table(df=
#        constructorResultsId  raceId  constructorId  points                date
# 0                         0      48            103    13.0 1956-01-22 00:00:00
# 1                         1      48              5    12.0 1956-01-22 00:00:00
# 2                         2      54            126     0.0 1956-08-05 00:00:00
# 3                         3      54            103    15.0 1956-08-05 00:00:00
# 4                         4      54              5     9.0 1956-08-05 00:00:00
# ...                     ...     ...            ...     ...                 ...
# 12285                 12285    1090              0    16.0 2023-07-30 13:00:00
# 12286                 12286    1090            210    10.0 2023-07-30 13:00:00
# 12287                 12287    1090            209     1.0 2023-07-30 13:00:00
# 12288                 12288    1090             49     0.0 2023-07-30 13:00:00
# 12289                 12289    1090            207     0.0 2023-07-30 13:00:00
#
# [12290 rows x 5 columns],
#   fkey_col_to_pkey_table={'raceId': 'races', 'constructorId': 'constructors'},
#   pkey_col=constructorResultsId,
#   time_col=date)
# Table Name: constructor_standings
# Table(df=
#        constructorStandingsId  raceId  constructorId  points  position  wins  \
# 0                           0      64            103     3.0         3     0
# 1                           1      64              5     6.0         2     0
# 2                           2      64             85     8.0         1     1
# 3                           3      65             85    16.0         1     2
# 4                           4      65             31     0.0         5     0
# ...                       ...     ...            ...     ...       ...   ...
# 13046                   13046    1090             49     9.0         9     0
# 13047                   13047    1090            210    57.0         6     0
# 13048                   13048    1090              2    11.0         7     0
# 13049                   13049    1090            209     3.0        10     0
# 13050                   13050    1090              0   103.0         5     0
#
#                      date
# 0     1958-01-19 00:00:00
# 1     1958-01-19 00:00:00
# 2     1958-01-19 00:00:00
# 3     1958-05-18 00:00:00
# 4     1958-05-18 00:00:00
# ...                   ...
# 13046 2023-07-30 13:00:00
# 13047 2023-07-30 13:00:00
# 13048 2023-07-30 13:00:00
# 13049 2023-07-30 13:00:00
# 13050 2023-07-30 13:00:00
#
# [13051 rows x 7 columns],
#   fkey_col_to_pkey_table={'raceId': 'races', 'constructorId': 'constructors'},
#   pkey_col=constructorStandingsId,
#   time_col=date)
# Table Name: qualifying
# Table(df=
#       qualifyId  raceId  driverId  constructorId  number  position  \
# 0             0     548        43             26      26        19
# 1             1     548       100             30      31        26
# 2             2     548        91             29      34        25
# 3             3     548        82             31      11        24
# 4             4     548       105             32      19        23
# ...         ...     ...       ...            ...     ...       ...
# 9810       9810    1090       842              5      16         2
# 9811       9811    1090       829              8       1         1
# 9812       9812    1090       816            209       3        19
# 9813       9813    1090         3            115      14         9
# 9814       9814    1090       807            207      27        20
#
#                     date
# 0    1994-03-26 00:00:00
# 1    1994-03-26 00:00:00
# 2    1994-03-26 00:00:00
# 3    1994-03-26 00:00:00
# 4    1994-03-26 00:00:00
# ...                  ...
# 9810 2023-07-29 13:00:00
# 9811 2023-07-29 13:00:00
# 9812 2023-07-29 13:00:00
# 9813 2023-07-29 13:00:00
# 9814 2023-07-29 13:00:00
#
# [9815 rows x 7 columns],
#   fkey_col_to_pkey_table={'raceId': 'races', 'driverId': 'drivers', 'constructorId': 'constructors'},
#   pkey_col=qualifyId,
#   time_col=date)
