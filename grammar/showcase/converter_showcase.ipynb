# %%
# %load_ext autoreload
# %autoreload 2

from showcase_helper import *
from relbench.datasets.f1 import F1Dataset
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
f1_dataset = F1Dataset()
helper = ConverterShowcaseHelper(f1_dataset)

# %%
helper.convert_query("""
                PREDICT AVG(results.position, 0, 10, days) > 10
                FOR EACH drivers.driverId WHERE AVG(results.position, -365, 0, days) < 30;
              """)
# Out:
# ========================================
#
#                 PREDICT AVG(results.position, 0, 10, days) > 10
#                 FOR EACH drivers.driverId WHERE AVG(results.position, -365, 0, days) < 30;
#
#
#                                 SELECT
#                                     hq.driverId AS fk,
#                                     hq.timestamp  AS timestamp,
#                                     CASE
#                                      WHEN tq.fk IS NOT NULL THEN TRUE
#                                      ELSE FALSE
#                                  END
#                                AS label
#                                 FROM
#                                     (
#                              SELECT
#                                  p.driverId AS driverId,
#                                  c.timestamp  AS timestamp,
#                              FROM
#                                  drivers p
#                              JOIN
#                                  (
#                         SELECT
#                             *
#                         FROM
#                             (
#                         SELECT
#                             tbl.driverId           AS fk,
#                             AVG(tbl.position) AS col_for_comp,
#                             time.timestamp     AS timestamp
#                         FROM
#                             timestamp_df time
#                         JOIN
#                             results tbl
#                         ON
#                             tbl.date >= time.timestamp + INTERVAL '-365 DAY'
#                             AND
#                             tbl.date < time.timestamp + INTERVAL '0 DAY'
#                         GROUP BY time.timestamp, tbl.driverId) tq
#                         WHERE
#                             col_for_comp < 30) c
#                              ON
#                                  c.fk = p.driverId
#                         ) hq
#                                 LEFT JOIN
#                                     (
#                         SELECT
#                             *
#                         FROM
#                             (
#                         SELECT
#                             tbl.driverId           AS fk,
#                             AVG(tbl.position) AS col_for_comp,
#                             time.timestamp     AS timestamp
#                         FROM
#                             timestamp_df time
#                         JOIN
#                             results tbl
#                         ON
#                             tbl.date >= time.timestamp + INTERVAL '0 DAY'
#                             AND
#                             tbl.date < time.timestamp + INTERVAL '10 DAY'
#                         GROUP BY time.timestamp, tbl.driverId) tq
#                         WHERE
#                             col_for_comp > 10) tq
#                                 ON
#                                     tq.fk = hq.driverId
#                                 AND
#                                     tq.timestamp = hq.timestamp
#                                 ORDER BY
#                                     hq.timestamp ASC, hq.driverId ASC
#                             ;
# Table(df=
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬─────────┐
# │  fk   │      timestamp      │  label  │
# │ int64 │    timestamp_ns     │ boolean │
# ├───────┼─────────────────────┼─────────┤
# │     1 │ 2010-01-01 00:00:00 │ false   │
# │     2 │ 2010-01-01 00:00:00 │ false   │
# │     3 │ 2010-01-01 00:00:00 │ false   │
# │     4 │ 2010-01-01 00:00:00 │ false   │
# │     5 │ 2010-01-01 00:00:00 │ false   │
# │     6 │ 2010-01-01 00:00:00 │ false   │
# │     7 │ 2010-01-01 00:00:00 │ false   │
# │     8 │ 2010-01-01 00:00:00 │ false   │
# │     9 │ 2010-01-01 00:00:00 │ false   │
# │    10 │ 2010-01-01 00:00:00 │ false   │
# │     · │          ·          │   ·     │
# │     · │          ·          │   ·     │
# │     · │          ·          │   ·     │
# │    67 │ 2010-05-05 00:00:00 │ false   │
# │    69 │ 2010-05-05 00:00:00 │ false   │
# │   153 │ 2010-05-05 00:00:00 │ false   │
# │   154 │ 2010-05-05 00:00:00 │ false   │
# │   155 │ 2010-05-05 00:00:00 │ true    │
# │   807 │ 2010-05-05 00:00:00 │ true    │
# │   808 │ 2010-05-05 00:00:00 │ true    │
# │   810 │ 2010-05-05 00:00:00 │ true    │
# │   811 │ 2010-05-05 00:00:00 │ false   │
# │   812 │ 2010-05-05 00:00:00 │ false   │
# ├───────┴─────────────────────┴─────────┤
# │ 3384 rows (20 shown)        3 columns │
# └───────────────────────────────────────┘
# >,
#   fkey_col_to_pkey_table=None,
#   pkey_col=None,
#   time_col=timestamp)
# ========================================

# %%
helper.convert_query("""
                PREDICT AVG(results.position, 0, 10, days) > 10
                FOR EACH drivers.driverId WHERE AVG(results.position, -365, 0, days) < 30 AND AVG(results.position, -365, 0, days) >= 0;
              """)
# Out:
# ========================================
#
#                 PREDICT AVG(results.position, 0, 10, days) > 10
#                 FOR EACH drivers.driverId WHERE AVG(results.position, -365, 0, days) < 30 AND AVG(results.position, -365, 0, days) >= 0;
#
#
#                                 SELECT
#                                     hq.driverId AS fk,
#                                     hq.timestamp  AS timestamp,
#                                     CASE
#                                      WHEN tq.fk IS NOT NULL THEN TRUE
#                                      ELSE FALSE
#                                  END
#                                AS label
#                                 FROM
#                                     (
#                              SELECT
#                                  p.driverId AS driverId,
#                                  c.timestamp  AS timestamp,
#                              FROM
#                                  drivers p
#                              JOIN
#                                  (
#                              SELECT
#                                  fk AS fk,
#                                  timestamp AS timestamp
#                              FROM
#                                  (
#                         SELECT
#                             *
#                         FROM
#                             (
#                         SELECT
#                             tbl.driverId           AS fk,
#                             AVG(tbl.position) AS col_for_comp,
#                             time.timestamp     AS timestamp
#                         FROM
#                             timestamp_df time
#                         JOIN
#                             results tbl
#                         ON
#                             tbl.date >= time.timestamp + INTERVAL '-365 DAY'
#                             AND
#                             tbl.date < time.timestamp + INTERVAL '0 DAY'
#                         GROUP BY time.timestamp, tbl.driverId) tq
#                         WHERE
#                             col_for_comp < 30) l
#                              INTERSECT
#                              SELECT
#                                  fk AS fk,
#                                  timestamp AS timestamp
#                              FROM (
#                         SELECT
#                             *
#                         FROM
#                             (
#                         SELECT
#                             tbl.driverId           AS fk,
#                             AVG(tbl.position) AS col_for_comp,
#                             time.timestamp     AS timestamp
#                         FROM
#                             timestamp_df time
#                         JOIN
#                             results tbl
#                         ON
#                             tbl.date >= time.timestamp + INTERVAL '-365 DAY'
#                             AND
#                             tbl.date < time.timestamp + INTERVAL '0 DAY'
#                         GROUP BY time.timestamp, tbl.driverId) tq
#                         WHERE
#                             col_for_comp >= 0) r
#                           ) c
#                              ON
#                                  c.fk = p.driverId
#                         ) hq
#                                 LEFT JOIN
#                                     (
#                         SELECT
#                             *
#                         FROM
#                             (
#                         SELECT
#                             tbl.driverId           AS fk,
#                             AVG(tbl.position) AS col_for_comp,
#                             time.timestamp     AS timestamp
#                         FROM
#                             timestamp_df time
#                         JOIN
#                             results tbl
#                         ON
#                             tbl.date >= time.timestamp + INTERVAL '0 DAY'
#                             AND
#                             tbl.date < time.timestamp + INTERVAL '10 DAY'
#                         GROUP BY time.timestamp, tbl.driverId) tq
#                         WHERE
#                             col_for_comp > 10) tq
#                                 ON
#                                     tq.fk = hq.driverId
#                                 AND
#                                     tq.timestamp = hq.timestamp
#                                 ORDER BY
#                                     hq.timestamp ASC, hq.driverId ASC
#                             ;
# Table(df=
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬─────────┐
# │  fk   │      timestamp      │  label  │
# │ int64 │    timestamp_ns     │ boolean │
# ├───────┼─────────────────────┼─────────┤
# │     1 │ 2010-01-01 00:00:00 │ false   │
# │     2 │ 2010-01-01 00:00:00 │ false   │
# │     3 │ 2010-01-01 00:00:00 │ false   │
# │     4 │ 2010-01-01 00:00:00 │ false   │
# │     5 │ 2010-01-01 00:00:00 │ false   │
# │     6 │ 2010-01-01 00:00:00 │ false   │
# │     7 │ 2010-01-01 00:00:00 │ false   │
# │     8 │ 2010-01-01 00:00:00 │ false   │
# │     9 │ 2010-01-01 00:00:00 │ false   │
# │    10 │ 2010-01-01 00:00:00 │ false   │
# │     · │          ·          │   ·     │
# │     · │          ·          │   ·     │
# │     · │          ·          │   ·     │
# │    67 │ 2010-05-05 00:00:00 │ false   │
# │    69 │ 2010-05-05 00:00:00 │ false   │
# │   153 │ 2010-05-05 00:00:00 │ false   │
# │   154 │ 2010-05-05 00:00:00 │ false   │
# │   155 │ 2010-05-05 00:00:00 │ true    │
# │   807 │ 2010-05-05 00:00:00 │ true    │
# │   808 │ 2010-05-05 00:00:00 │ true    │
# │   810 │ 2010-05-05 00:00:00 │ true    │
# │   811 │ 2010-05-05 00:00:00 │ false   │
# │   812 │ 2010-05-05 00:00:00 │ false   │
# ├───────┴─────────────────────┴─────────┤
# │ 3384 rows (20 shown)        3 columns │
# └───────────────────────────────────────┘
# >,
#   fkey_col_to_pkey_table=None,
#   pkey_col=None,
#   time_col=timestamp)
# ========================================

# %%
helper.convert_query("""
                PREDICT AVG(results.position, 0, 100, days) < 100
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT AVG(results.position, 0, 100, days) < 100
#                 FOR EACH drivers.driverId;
#
#
#                                 SELECT
#                                     p.driverId AS fk,
#                                     time.timestamp AS timestamp,
#                                     CASE
#                                      WHEN tq.fk IS NOT NULL THEN TRUE
#                                      ELSE FALSE
#                                  END
#                                AS label
#                                 FROM
#                                     drivers p
#                                 CROSS JOIN
#                                     timestamp_df time
#                                 LEFT JOIN
#                                     (
#                         SELECT
#                             *
#                         FROM
#                             (
#                         SELECT
#                             tbl.driverId           AS fk,
#                             AVG(tbl.position) AS col_for_comp,
#                             time.timestamp     AS timestamp
#                         FROM
#                             timestamp_df time
#                         JOIN
#                             results tbl
#                         ON
#                             tbl.date >= time.timestamp + INTERVAL '0 DAY'
#                             AND
#                             tbl.date < time.timestamp + INTERVAL '100 DAY'
#                         GROUP BY time.timestamp, tbl.driverId) tq
#                         WHERE
#                             col_for_comp < 100) tq
#                                 ON
#                                     tq.fk = p.driverId
#                                     AND
#                                     tq.timestamp = time.timestamp
#                                 ORDER BY
#                                     time.timestamp ASC, p.driverId ASC
#                             ;
# Table(df=
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬─────────┐
# │  fk   │      timestamp      │  label  │
# │ int64 │    timestamp_ns     │ boolean │
# ├───────┼─────────────────────┼─────────┤
# │     1 │ 2010-01-01 00:00:00 │ true    │
# │     2 │ 2010-01-01 00:00:00 │ false   │
# │     3 │ 2010-01-01 00:00:00 │ true    │
# │     4 │ 2010-01-01 00:00:00 │ true    │
# │     5 │ 2010-01-01 00:00:00 │ true    │
# │     6 │ 2010-01-01 00:00:00 │ false   │
# │     7 │ 2010-01-01 00:00:00 │ false   │
# │     8 │ 2010-01-01 00:00:00 │ false   │
# │     9 │ 2010-01-01 00:00:00 │ true    │
# │    10 │ 2010-01-01 00:00:00 │ false   │
# │     · │          ·          │   ·     │
# │     · │          ·          │   ·     │
# │     · │          ·          │   ·     │
# │   564 │ 2010-01-12 00:00:00 │ false   │
# │   565 │ 2010-01-12 00:00:00 │ false   │
# │   566 │ 2010-01-12 00:00:00 │ false   │
# │   567 │ 2010-01-12 00:00:00 │ false   │
# │   568 │ 2010-01-12 00:00:00 │ false   │
# │   569 │ 2010-01-12 00:00:00 │ false   │
# │   570 │ 2010-01-12 00:00:00 │ false   │
# │   571 │ 2010-01-12 00:00:00 │ false   │
# │   572 │ 2010-01-12 00:00:00 │ false   │
# │   573 │ 2010-01-12 00:00:00 │ false   │
# ├───────┴─────────────────────┴─────────┤
# │ ? rows                      3 columns │
# │ (>9999 rows, 20 shown)                │
# └───────────────────────────────────────┘
# >,
#   fkey_col_to_pkey_table=None,
#   pkey_col=None,
#   time_col=timestamp)
# ========================================

# %%
helper.convert_query("""
                PREDICT COUNT(results.*, 0, 100, days) < 100
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT COUNT(results.*, 0, 100, days) < 100
#                 FOR EACH drivers.driverId;
#
#
#                                 SELECT
#                                     p.driverId AS fk,
#                                     time.timestamp AS timestamp,
#                                     CASE
#                                      WHEN tq.fk IS NOT NULL THEN TRUE
#                                      ELSE FALSE
#                                  END
#                                AS label
#                                 FROM
#                                     drivers p
#                                 CROSS JOIN
#                                     timestamp_df time
#                                 LEFT JOIN
#                                     (
#                         SELECT
#                             *
#                         FROM
#                             (
#                         SELECT
#                             tbl.driverId           AS fk,
#                             COUNT(tbl.*) AS col_for_comp,
#                             time.timestamp     AS timestamp
#                         FROM
#                             timestamp_df time
#                         JOIN
#                             results tbl
#                         ON
#                             tbl.date >= time.timestamp + INTERVAL '0 DAY'
#                             AND
#                             tbl.date < time.timestamp + INTERVAL '100 DAY'
#                         GROUP BY time.timestamp, tbl.driverId) tq
#                         WHERE
#                             col_for_comp < 100) tq
#                                 ON
#                                     tq.fk = p.driverId
#                                     AND
#                                     tq.timestamp = time.timestamp
#                                 ORDER BY
#                                     time.timestamp ASC, p.driverId ASC
#                             ;
# Table(df=
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬─────────┐
# │  fk   │      timestamp      │  label  │
# │ int64 │    timestamp_ns     │ boolean │
# ├───────┼─────────────────────┼─────────┤
# │     1 │ 2010-01-01 00:00:00 │ true    │
# │     2 │ 2010-01-01 00:00:00 │ false   │
# │     3 │ 2010-01-01 00:00:00 │ true    │
# │     4 │ 2010-01-01 00:00:00 │ true    │
# │     5 │ 2010-01-01 00:00:00 │ true    │
# │     6 │ 2010-01-01 00:00:00 │ false   │
# │     7 │ 2010-01-01 00:00:00 │ false   │
# │     8 │ 2010-01-01 00:00:00 │ false   │
# │     9 │ 2010-01-01 00:00:00 │ true    │
# │    10 │ 2010-01-01 00:00:00 │ true    │
# │     · │          ·          │  ·      │
# │     · │          ·          │  ·      │
# │     · │          ·          │  ·      │
# │   564 │ 2010-01-12 00:00:00 │ false   │
# │   565 │ 2010-01-12 00:00:00 │ false   │
# │   566 │ 2010-01-12 00:00:00 │ false   │
# │   567 │ 2010-01-12 00:00:00 │ false   │
# │   568 │ 2010-01-12 00:00:00 │ false   │
# │   569 │ 2010-01-12 00:00:00 │ false   │
# │   570 │ 2010-01-12 00:00:00 │ false   │
# │   571 │ 2010-01-12 00:00:00 │ false   │
# │   572 │ 2010-01-12 00:00:00 │ false   │
# │   573 │ 2010-01-12 00:00:00 │ false   │
# ├───────┴─────────────────────┴─────────┤
# │ ? rows                      3 columns │
# │ (>9999 rows, 20 shown)                │
# └───────────────────────────────────────┘
# >,
#   fkey_col_to_pkey_table=None,
#   pkey_col=None,
#   time_col=timestamp)
# ========================================

# %%
helper.convert_query("""
                PREDICT AVG(results.position, 0, 100, days)
                FOR EACH drivers.driverId;
              """)
# Out:
# ========================================
#
#                 PREDICT AVG(results.position, 0, 100, days)
#                 FOR EACH drivers.driverId;
#
#
#                                 SELECT
#                                     p.driverId AS fk,
#                                     time.timestamp AS timestamp,
#                                     tq.col_for_comp AS label
#                                 FROM
#                                     drivers p
#                                 CROSS JOIN
#                                     timestamp_df time
#                                 LEFT JOIN
#                                     (
#                         SELECT
#                             tbl.driverId           AS fk,
#                             AVG(tbl.position) AS col_for_comp,
#                             time.timestamp     AS timestamp
#                         FROM
#                             timestamp_df time
#                         JOIN
#                             results tbl
#                         ON
#                             tbl.date >= time.timestamp + INTERVAL '0 DAY'
#                             AND
#                             tbl.date < time.timestamp + INTERVAL '100 DAY'
#                         GROUP BY time.timestamp, tbl.driverId) tq
#                                 ON
#                                     tq.fk = p.driverId
#                                     AND
#                                     tq.timestamp = time.timestamp
#                                 ORDER BY
#                                     time.timestamp ASC, p.driverId ASC
#                             ;
# Table(df=
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬───────────────────┐
# │  fk   │      timestamp      │       label       │
# │ int64 │    timestamp_ns     │      double       │
# ├───────┼─────────────────────┼───────────────────┤
# │     1 │ 2010-01-01 00:00:00 │               5.0 │
# │     2 │ 2010-01-01 00:00:00 │              NULL │
# │     3 │ 2010-01-01 00:00:00 │ 4.333333333333333 │
# │     4 │ 2010-01-01 00:00:00 │               6.0 │
# │     5 │ 2010-01-01 00:00:00 │              14.0 │
# │     6 │ 2010-01-01 00:00:00 │              NULL │
# │     7 │ 2010-01-01 00:00:00 │              NULL │
# │     8 │ 2010-01-01 00:00:00 │              NULL │
# │     9 │ 2010-01-01 00:00:00 │ 5.666666666666667 │
# │    10 │ 2010-01-01 00:00:00 │              NULL │
# │     · │          ·          │                ·  │
# │     · │          ·          │                ·  │
# │     · │          ·          │                ·  │
# │   564 │ 2010-01-12 00:00:00 │              NULL │
# │   565 │ 2010-01-12 00:00:00 │              NULL │
# │   566 │ 2010-01-12 00:00:00 │              NULL │
# │   567 │ 2010-01-12 00:00:00 │              NULL │
# │   568 │ 2010-01-12 00:00:00 │              NULL │
# │   569 │ 2010-01-12 00:00:00 │              NULL │
# │   570 │ 2010-01-12 00:00:00 │              NULL │
# │   571 │ 2010-01-12 00:00:00 │              NULL │
# │   572 │ 2010-01-12 00:00:00 │              NULL │
# │   573 │ 2010-01-12 00:00:00 │              NULL │
# ├───────┴─────────────────────┴───────────────────┤
# │ ? rows (>9999 rows, 20 shown)         3 columns │
# └─────────────────────────────────────────────────┘
# >,
#   fkey_col_to_pkey_table=None,
#   pkey_col=None,
#   time_col=timestamp)
# ========================================

# %%
helper.convert_query("""
                PREDICT AVG(results.position, 0, 100, days)
                FOR EACH drivers.driverId WHERE COUNT(results.*, 0, 100, days) > 1
                WHERE AVG(results.position, -365, 0, days) < 30;
              """)
# Out:
# ========================================
#
#                 PREDICT AVG(results.position, 0, 100, days)
#                 FOR EACH drivers.driverId WHERE COUNT(results.*, 0, 100, days) > 1
#                 WHERE AVG(results.position, -365, 0, days) < 30;
#
#
#                             SELECT
#                                 s.fk fk,
#                                 s.timestamp,
#                                 s.label
#                             FROM
#                                 (
#                                 SELECT
#                                     hq.driverId AS fk,
#                                     hq.timestamp  AS timestamp,
#                                     tq.col_for_comp AS label
#                                 FROM
#                                     (
#                              SELECT
#                                  p.driverId AS driverId,
#                                  c.timestamp  AS timestamp,
#                              FROM
#                                  drivers p
#                              JOIN
#                                  (
#                         SELECT
#                             *
#                         FROM
#                             (
#                         SELECT
#                             tbl.driverId           AS fk,
#                             COUNT(tbl.*) AS col_for_comp,
#                             time.timestamp     AS timestamp
#                         FROM
#                             timestamp_df time
#                         JOIN
#                             results tbl
#                         ON
#                             tbl.date >= time.timestamp + INTERVAL '0 DAY'
#                             AND
#                             tbl.date < time.timestamp + INTERVAL '100 DAY'
#                         GROUP BY time.timestamp, tbl.driverId) tq
#                         WHERE
#                             col_for_comp > 1) c
#                              ON
#                                  c.fk = p.driverId
#                         ) hq
#                                 LEFT JOIN
#                                     (
#                         SELECT
#                             tbl.driverId           AS fk,
#                             AVG(tbl.position) AS col_for_comp,
#                             time.timestamp     AS timestamp
#                         FROM
#                             timestamp_df time
#                         JOIN
#                             results tbl
#                         ON
#                             tbl.date >= time.timestamp + INTERVAL '0 DAY'
#                             AND
#                             tbl.date < time.timestamp + INTERVAL '100 DAY'
#                         GROUP BY time.timestamp, tbl.driverId) tq
#                                 ON
#                                     tq.fk = hq.driverId
#                                 AND
#                                     tq.timestamp = hq.timestamp
#                                 ORDER BY
#                                     hq.timestamp ASC, hq.driverId ASC
#                             ) s
#                             JOIN
#                                 (
#                         SELECT
#                             *
#                         FROM
#                             (
#                         SELECT
#                             tbl.driverId           AS fk,
#                             AVG(tbl.position) AS col_for_comp,
#                             time.timestamp     AS timestamp
#                         FROM
#                             timestamp_df time
#                         JOIN
#                             results tbl
#                         ON
#                             tbl.date >= time.timestamp + INTERVAL '-365 DAY'
#                             AND
#                             tbl.date < time.timestamp + INTERVAL '0 DAY'
#                         GROUP BY time.timestamp, tbl.driverId) tq
#                         WHERE
#                             col_for_comp < 30) w
#                             ON
#                                 w.fk = s.fk
#                             AND
#                                 w.timestamp = s.timestamp
#                             ORDER BY
#                                 s.timestamp ASC, s.fk ASC
#
#                          ;
# Table(df=
# <bound method pybind11_detail_function_record_v1_system_libstdcpp_gxx_abi_1xxx_use_cxx11_abi_1.df of ┌───────┬─────────────────────┬────────────────────┐
# │  fk   │      timestamp      │       label        │
# │ int64 │    timestamp_ns     │       double       │
# ├───────┼─────────────────────┼────────────────────┤
# │     1 │ 2010-01-01 00:00:00 │                5.0 │
# │     3 │ 2010-01-01 00:00:00 │  4.333333333333333 │
# │     4 │ 2010-01-01 00:00:00 │                6.0 │
# │     5 │ 2010-01-01 00:00:00 │               14.0 │
# │     9 │ 2010-01-01 00:00:00 │  5.666666666666667 │
# │    10 │ 2010-01-01 00:00:00 │               NULL │
# │    13 │ 2010-01-01 00:00:00 │                4.0 │
# │    15 │ 2010-01-01 00:00:00 │               17.0 │
# │    16 │ 2010-01-01 00:00:00 │                8.5 │
# │    17 │ 2010-01-01 00:00:00 │  6.333333333333333 │
# │     · │          ·          │                ·   │
# │     · │          ·          │                ·   │
# │     · │          ·          │                ·   │
# │    30 │ 2010-05-05 00:00:00 │              9.375 │
# │    37 │ 2010-05-05 00:00:00 │               11.0 │
# │    67 │ 2010-05-05 00:00:00 │ 11.166666666666666 │
# │   153 │ 2010-05-05 00:00:00 │ 12.166666666666666 │
# │   155 │ 2010-05-05 00:00:00 │  9.166666666666666 │
# │   807 │ 2010-05-05 00:00:00 │               12.5 │
# │   808 │ 2010-05-05 00:00:00 │              12.25 │
# │   810 │ 2010-05-05 00:00:00 │               18.4 │
# │   811 │ 2010-05-05 00:00:00 │ 18.666666666666668 │
# │   812 │ 2010-05-05 00:00:00 │               17.8 │
# ├───────┴─────────────────────┴────────────────────┤
# │ 2384 rows (20 shown)                   3 columns │
# └──────────────────────────────────────────────────┘
# >,
#   fkey_col_to_pkey_table=None,
#   pkey_col=None,
#   time_col=timestamp)
# ========================================
